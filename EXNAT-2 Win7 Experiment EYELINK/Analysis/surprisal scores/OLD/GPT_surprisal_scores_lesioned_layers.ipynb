# %% [markdown]
# # **Script for Calculating Surprisal Scores on Different Time Scales**

# %% [markdown]
# This script was written by [Merle Schuckart](merle.schuckart@uni-luebeck.de) with a lot of help from [Lea-Maria Schmitt](https://www.predictivebrainlab.com/people-details/lea-maria-schmitt/) and [a very nice Stackoverflow user](https://stackoverflow.com/users/1949646/kaybee).
#
# Version: 26th of April 2023

# %% [markdown]
# ## Import modules

# %%
# %%capture
# (disable %%capture to print output in console)

# Import modules:

! pip install transformers
from transformers import AutoTokenizer, AutoModelForCausalLM #,AutoModelWithLMHead # will be deprecated soon-ish
import torch
import tensorflow as tf

import re # for re.search()
import numpy as np # for maths functions
import pandas as pd # for dfs
import csv # for reading in csv properly
from google.colab import files # for downloading files

# %% [markdown]
# ## Load tokenizer & model

# %%
# %%capture
# (disable %%capture to print output in console)

# download pre-trained German GPT-2 model & tokenizer
tokenizer = AutoTokenizer.from_pretrained("dbmdz/german-gpt2")

# initialise the model
model = AutoModelForCausalLM.from_pretrained("dbmdz/german-gpt2", pad_token_id = tokenizer.eos_token_id)

# %% [markdown]
# ## Test: How to lesion single layers (aka zeroing-out layers)
#
# This is just an example to show how you can set the weights in 1 specific layer to 0:
#
# We first make a prediction with the full model, then we lesion layer 5 by setting all pre-trained network weights to 0, then we make a prediction for the same input prompt again.
#
# The second prediction should differ from the first one.
#
# If you run this chunk multiple times and set a different layer to lesion every time, you can lesion multiple layers. The prediction should get worse with each layer you turn off.

# %%
# set input text
input_text = ["Orlando", "liebte", "von", "Natur", "aus", "einsame", "Orte,", "weite", "Ausblicke", "und", "das", "Gefühl,", "für", "immer", "und", "ewig"] # correct continuation: "allein zu sein."
# turn list of words into 1 text string:
input_text = ' '.join(input_text)
# tokenize text
ids_list = tokenizer.encode(input_text)
# put the token IDs into array
ids_array = np.expand_dims((ids_list), axis = 0)

# predict the next x tokens
output = model.generate(torch.tensor(ids_array), 
                        return_dict_in_generate = True, 
                        output_scores = True, 
                        max_new_tokens = 10) # set output length here!

# decode generated token
# generate list of token ids from model output
predicted_ids = output.sequences
# decode output to get words instead of token ids
prediction = tokenizer.decode(predicted_ids.numpy().tolist()[0])

print('\n***Before zeroing out layer***')
print("prediction:", prediction)


### Lesion 1 Layer in the Model

# choose layer to lesion - example: lesion layer 5
layer_idx = 5

# Find all parameter names for this layer

# The parameter names are basically the names of the weight tensors. 
# Each weight tensor is stored in the model.state_dict with the corresponding 
# key in the dict being the parameter name. 

# The parameter names of layer X all include the string "transformer.h.X." 
# with X being the index of layer X (e.g. "transformer.h.5." for layer_idx = 5). 

# So to get a list of all parameter names for the layer we want to lesion, we need to filter 
# all keys in the model.state_dict for the string "transformer.h.", followed by the layer index: 
paramnames = filter(lambda s: re.search(f'transformer.h\.{layer_idx}\.',s) is not None, model.state_dict().keys())

# set the weights of these parameters to 0
# loop parameter names
for paramname in paramnames:
  # get weight tensor from model.state_dict
  # w is a tensor containing the layer's weights
  w = model.state_dict()[paramname]
  
  # if the tensor w has more than 0 dimension (aka is not empty), 
  # you can set all weights in the tensor to 0.
  if w.ndim > 0:
    w[:] = 0

# FINISHED UPDATING MODEL - LAYER 5 IS NOW LESIONED


# generate prediction using updated model:
# predict the next x tokens
output = model.generate(torch.tensor(ids_array), 
                        return_dict_in_generate = True, 
                        output_scores = True, 
                        max_new_tokens = 10) # set output length here!

# decode generated token
# generate list of token ids from model output
predicted_ids = output.sequences
# decode output to get words instead of token ids
prediction = tokenizer.decode(predicted_ids.numpy().tolist()[0])

print('\n***After zeroing out layer***')
print("prediction:", prediction)
# Out:
# ***Before zeroing out layer***
# prediction: Orlando liebte von Natur aus einsame Orte, weite Ausblicke und das Gefühl, für immer und ewig in der Nähe zu sein.
# Er war ein
#
# ***After zeroing out layer***
# prediction: Orlando liebte von Natur aus einsame Orte, weite Ausblicke und das Gefühl, für immer und ewig zu sein.
# Die Natur ist ein Paradies für

# %% [markdown]
# # Surprisal Scores
#
# Now comes the real deal: We need surprisal scores for each word in the EXNAT-1 texts on each time scale (time scale = layer).

# %% [markdown]
# ## Load Texts

# %%
# Load texts

# Important: You need to put the CSV called "Texts_surprisal_scores.csv" (see the surprisal score folder in the EXNAT-1 analysis folder on Github) 
# into the files section (see menu on the left) before running this chunk.

# read in csv with texts
texts_df = pd.read_csv('/content/Texts_surprisal_scores.csv', 
                       sep = ";", 
                       quoting = csv.QUOTE_NONE, 
                       quotechar = None)

# Check dataframe - show all rows and columns in console:
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
#print(texts_df["word_punct"])

# get unique text numbers in texts_df
text_nrs = list(set(texts_df["text_nr"]))
#print("preparing surprisal scores for the following texts:")
#print(text_nrs)

# %% [markdown]
# ### Settings

# %%
# How long should the context chunk be?
# I decided I want 50 words, but that's a completely arbitrary value. 
# Just make sure it's less than 300, ideally <= 100 so you still have some trials left.
context_size = 50

# Prepare surprisal score lists

surprisal_1  = [] # layer  1 at idx  0
surprisal_2  = [] # layer  2 at idx  1
surprisal_3  = [] # layer  3 at idx  2
surprisal_4  = [] # layer  4 at idx  3
surprisal_5  = [] # layer  5 at idx  4
surprisal_6  = [] # layer  6 at idx  5
surprisal_7  = [] # layer  7 at idx  6
surprisal_8  = [] # layer  8 at idx  7
surprisal_9  = [] # layer  9 at idx  8
surprisal_10 = [] # layer 10 at idx  9
surprisal_11 = [] # layer 11 at idx 10
surprisal_12 = [] # layer 12 at idx 11

# ------------------------

# Load full model again:

model = AutoModelForCausalLM.from_pretrained("dbmdz/german-gpt2", pad_token_id = tokenizer.eos_token_id)
print("Loaded model with pretrained weights again - we're all set!")

# ------------------------

# Check how many layers the model has 
# (should be 12, but better safe than sorry)

# Placeholder set to store unique layer indices:
layer_indices = set()

# Loop keys in the model.state_dict dictionary:
for key in model.state_dict().keys():
    # Use regex to check if the current key (aka parameter name) 
    # contains the string "transformer.h." followed by 1 or more digits
    target_string = re.search(r'transformer\.h\.(\d+)\.', key)

    # If there is one, add index to set, 
    # so we collect each index only once (there are 
    # always several tensors for 1 layer)
    if target_string:
        # Get layer index from match object "target_string",
        # then convert layer index from string to integer
        layer_idx = int(target_string.group(1))
        # We only need the unique indices, so add to set we created 
        # before the loop - this will only store indices 
        # that are not already stored in the set:
        layer_indices.add(layer_idx)

# get length of set
num_layers = len(layer_indices)
# show number of layers in console
print("Number of layers in the model:", num_layers)
# Out:
# Loaded model with pretrained weights again - we're all set!
# Number of layers in the model: 12

# %% [markdown]
# ### Compute Surprisal Scores
#
# #### Plan for now:
#
# Loop the layers:
# - Load the full model with the pretrained weights
# - Lesion all layers in the model except for the current layer
# - Loop words:
#     - compute surprisal score for each ID in the current word
#     - multiply ID surprisal scores to get word surprisal score
# - add surprisal score columns to text df and download file

# %%
""" Loop all 12 layers """
for curr_layer_idx in range(num_layers):

    print("\n\n\nStarting to compute surprisal scores for layer", curr_layer_idx+1, 
          ".\nZeroing out weights from the other layers now.\n\n")
    
    # get the list we want to save all surprisal scores for this time scale in.
    # The name of the list depends on the layer index, 
    # so get reference to correct list like this:
    curr_TS_list = eval(f"surprisal_{curr_layer_idx + 1}")

    # Load model with pretrained weights again        
    model = AutoModelForCausalLM.from_pretrained("dbmdz/german-gpt2", pad_token_id = tokenizer.eos_token_id)
    print("Loaded full model with pretrained weights!")

    """ Loop layers again, lesion each of them, 
        but skip layer if it's the layer we want to keep """
    for lesion_layer_idx in range(num_layers):
      
      # If the layer is the layer we want to keep, go to next iteration:
      if lesion_layer_idx == curr_layer_idx:
        print("keeping weights for layer", lesion_layer_idx+1)
        continue
      
      # If it's one of the other layers, exterminate! 
      # (Please read the last word in a dalek voice - thanks.)   
      else:
        print("zeroing out weights for layer", lesion_layer_idx+1)

        # Find all parameter names for the layer we want to lesion
        # (See more detailed comments in the example at the beginning of this script!)
        paramnames = filter(lambda s: re.search(f'transformer.h\.{lesion_layer_idx}\.',s) is not None, model.state_dict().keys())

        # set the weights of these parameters to 0
        # loop parameter names
        for paramname in paramnames:
          # get weight tensor from model.state_dict
          # w is a tensor containing the layer's weights
          w = model.state_dict()[paramname]
          
          # if the tensor w has more than 0 dimension (aka is not empty), 
          # you can set all weights in the tensor to 0.
          if w.ndim > 0:
            w[:] = 0

    print("\n\nModel weights are updated! Starting to compute surprisal scores now.\n")

    # -----------------------------------------

    """ Loop texts """
    for text_nr in text_nrs:
      # get subset of df with current text
      curr_text = texts_df[texts_df["text_nr"] == text_nr]

      """ Loop words & calculate surprisal score for each """
      
      # context_size is the size of the input text chunk, I set it as 50.
      # The first 50 words don't get surprisal scores, 
      # so assign None values instead.
      curr_TS_list.extend([None] * context_size)

      # loop words, start at word with index = 50 (aka the 51st word)
      for word_idx in range(context_size, len(curr_text["word_punct"])):

        """ prepare context chunk """
        # get 50 previous words (context chunk of size context_size)
        previous_words = list(curr_text["word_punct"])[word_idx - context_size : word_idx]

        # turn list of previous words into 1 text string
        previous_words = ' '.join(previous_words)

        # generate token ids for each of the x previous words
        ids_list = tokenizer.encode(previous_words)
        # put the token IDs into an array
        ids_array = np.expand_dims((ids_list), axis = 0) 

        """ prepare actual next word """
        # We should also predict punctuation. 
        # It's not like the words are shown without punctuation on screen.
        actual_word = list(curr_text["word_punct"])[word_idx]

        # Problem: actual word might have multiple token IDs
        # --> get all IDs for current word
        act_word_id = tokenizer.encode(actual_word) 
        # Output looks somewhat like this: [44, 305, 479, 5283]
        
        """ loop IDs of current word """
        curr_id_probs = []
        for curr_id in act_word_id:

            print("computing probability for ID " +  str(curr_id) + " of word " + actual_word)
              
            # generate probabilities for each possible token being the actual next token
            output = model.generate(torch.tensor(ids_array),
                                    return_dict_in_generate = True, 
                                    output_scores = True, 
                                    max_new_tokens = 1) # set output length here - 1 because I only want 1 token
            
            # read out probabilities for all IDs
            logits = output.scores[0] # logits = probabilities with range [0,1] transformed to range [inf, -inf]
            probs = tf.nn.softmax(logits) # transform logits back to probabilities

            # get probability for actual ID being the next one & append it to 
            # array with probabilities of all IDs for current word
            curr_id_probs.append(probs.numpy()[0][curr_id]) 

            # append current token ID to list of previous words (if there are any) 
            # reason: The previous parts of the word are part of the context.
            ids_list = np.append(ids_list, curr_id)
            ids_array = np.expand_dims((ids_list), axis = 0) # put the token IDs into an array

        # multiply all probabilities for current word:
        act_word_prob = np.prod(curr_id_probs)
        
        # transform probability value into surprisal score (negative log of the probability)
        # negative log = log(1 / x) with x being the value you want to get the negative log of.
        # I use e as a base value for the log here.
        surprisal_score = np.log( 1 / act_word_prob )

        # if surprisal score == Inf, set surprisal score to 100
        if surprisal_score == float('inf'):
          surprisal_score = 100

        # collect surprisal score in array for all surprisal scores of current time scale
        curr_TS_list.append(surprisal_score)
        print("\nSurprisal score for actual word " + actual_word +" is " + str(surprisal_score) + ".")
        print("Text Nr = " + str(text_nr) + " - Trial Nr = " + str(word_idx))
        print(" --------------- ")

print("\n\n\nfinished computing surprisal scores\n\n")

# append new surprisal score columns to text_df
texts_df = texts_df.assign(surprisal_1  = surprisal_1, 
                           surprisal_2  = surprisal_2,
                           surprisal_3  = surprisal_3,
                           surprisal_4  = surprisal_4,
                           surprisal_5  = surprisal_5,
                           surprisal_6  = surprisal_6,
                           surprisal_7  = surprisal_7,
                           surprisal_8  = surprisal_8,
                           surprisal_9  = surprisal_9,
                           surprisal_10 = surprisal_10,
                           surprisal_11 = surprisal_11,
                           surprisal_12 = surprisal_12)

# print first 370 rows of df to check if it looks correct
# (depending on chunk size x, first x values of a text should be None values)
#print(texts_df.head(370)) 

""" download texts_df as surprisal_scores.csv """
texts_df.to_csv('surprisal_scores_lesioned_layers.csv', encoding = 'utf-8-sig') 
files.download("surprisal_scores.csv")
# Out:
# Starting to compute surprisal scores for layer 1 .
# Zeroing out weights from the other layers now.
#
#
# Loaded full model with pretrained weights!
# keeping weights for layer 1
# zeroing out weights for layer 2
# zeroing out weights for layer 3
# zeroing out weights for layer 4
# zeroing out weights for layer 5
# zeroing out weights for layer 6
# zeroing out weights for layer 7
# zeroing out weights for layer 8
# zeroing out weights for layer 9
# zeroing out weights for layer 10
# zeroing out weights for layer 11
# zeroing out weights for layer 12
#
#
# Model weights are updated! Starting to compute surprisal scores now.
#
# computing probability for ID 320 of word der
#
# Surprisal score for actual word der is 11.968019390800702.
# Text Nr = text_08 - Trial Nr = 50
#  ---------------
# computing probability for ID 20306 of word Felsenstadt
# computing probability for ID 388 of word Felsenstadt
# computing probability for ID 1483 of word Felsenstadt
#
# Surprisal score for actual word Felsenstadt is 32.97529346233736.
# Text Nr = text_08 - Trial Nr = 51
#  ---------------
# computing probability for ID 14857 of word mitten
#
# Surprisal score for actual word mitten is 8.625889860711263.
# Text Nr = text_08 - Trial Nr = 52
#  ---------------
# computing probability for ID 269 of word in
#
# Surprisal score for actual word in is 7.666775920122574.
# Text Nr = text_08 - Trial Nr = 53
#  ---------------
# computing probability for ID 320 of word der
#
# Surprisal score for actual word der is 12.98692642312109.
# Text Nr = text_08 - Trial Nr = 54
#  ---------------
# computing probability for ID 59 of word Wüste
# computing probability for ID 6211 of word Wüste
#
# Surprisal score for actual word Wüste is 26.186319196971933.
# Text Nr = text_08 - Trial Nr = 55
#  ---------------
# computing probability for ID 46 of word Jordaniens.
# computing probability for ID 635 of word Jordaniens.
# computing probability for ID 2924 of word Jordaniens.
# computing probability for ID 87 of word Jordaniens.
# computing probability for ID 18 of word Jordaniens.
#
# Surprisal score for actual word Jordaniens. is 42.43662308769316.
# Text Nr = text_08 - Trial Nr = 56
#  ---------------
# computing probability for ID 425 of word Die
#
# Surprisal score for actual word Die is 5.063025437645413.
# Text Nr = text_08 - Trial Nr = 57
#  ---------------
# computing probability for ID 8891 of word Metropole
# computing probability for ID 36424 of word Metropole
#
# Surprisal score for actual word Metropole is 20.641603399227073.
# Text Nr = text_08 - Trial Nr = 58
#  ---------------
# computing probability for ID 982 of word war
#
# Surprisal score for actual word war is 15.473113423519854.
# Text Nr = text_08 - Trial Nr = 59
#  ---------------
# computing probability for ID 42850 of word einst
#
# Surprisal score for actual word einst is 17.297770304497092.
# Text Nr = text_08 - Trial Nr = 60
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 12.4358018881437.
# Text Nr = text_08 - Trial Nr = 61
#  ---------------
# computing probability for ID 49192 of word Hauptstadt
#
# Surprisal score for actual word Hauptstadt is 16.39417005912001.
# Text Nr = text_08 - Trial Nr = 62
#  ---------------
# computing probability for ID 320 of word der
#
# Surprisal score for actual word der is 8.092761155485192.
# Text Nr = text_08 - Trial Nr = 63
#  ---------------
# computing probability for ID 50 of word Nabatäer.
# computing probability for ID 421 of word Nabatäer.
# computing probability for ID 297 of word Nabatäer.
# computing probability for ID 27031 of word Nabatäer.
# computing probability for ID 18 of word Nabatäer.
#
# Surprisal score for actual word Nabatäer. is 61.00973813527273.
# Text Nr = text_08 - Trial Nr = 64
#  ---------------
# computing probability for ID 4511 of word Zwei
#
# Surprisal score for actual word Zwei is 9.777182483546225.
# Text Nr = text_08 - Trial Nr = 65
#  ---------------
# computing probability for ID 8234 of word Jahrhunderte
# computing probability for ID 7963 of word Jahrhunderte
#
# Surprisal score for actual word Jahrhunderte is 19.791126500516306.
# Text Nr = text_08 - Trial Nr = 66
#  ---------------
# computing probability for ID 2495 of word beherrschten
# computing probability for ID 1776 of word beherrschten
# computing probability for ID 9732 of word beherrschten
#
# Surprisal score for actual word beherrschten is 35.946600891194564.
# Text Nr = text_08 - Trial Nr = 67
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 12.664874347937.
# Text Nr = text_08 - Trial Nr = 68
#  ---------------
# computing probability for ID 50 of word Nabatäer
# computing probability for ID 421 of word Nabatäer
# computing probability for ID 297 of word Nabatäer
# computing probability for ID 27031 of word Nabatäer
#
# Surprisal score for actual word Nabatäer is 57.93567967189839.
# Text Nr = text_08 - Trial Nr = 69
#  ---------------
# computing probability for ID 27161 of word große
#
# Surprisal score for actual word große is 11.636561690773181.
# Text Nr = text_08 - Trial Nr = 70
#  ---------------
# computing probability for ID 28034 of word Teile
#
# Surprisal score for actual word Teile is 17.407156094884293.
# Text Nr = text_08 - Trial Nr = 71
#  ---------------
# computing probability for ID 2632 of word des
#
# Surprisal score for actual word des is 10.572463621835304.
# Text Nr = text_08 - Trial Nr = 72
#  ---------------
# computing probability for ID 19999 of word Handels
#
# Surprisal score for actual word Handels is 20.325614497785246.
# Text Nr = text_08 - Trial Nr = 73
#  ---------------
# computing probability for ID 487 of word im
#
# Surprisal score for actual word im is 9.732887134603072.
# Text Nr = text_08 - Trial Nr = 74
#  ---------------
# computing probability for ID 50 of word Nahen
# computing probability for ID 29491 of word Nahen
#
# Surprisal score for actual word Nahen is 36.291697639583994.
# Text Nr = text_08 - Trial Nr = 75
#  ---------------
# computing probability for ID 51 of word Osten.
# computing probability for ID 448 of word Osten.
# computing probability for ID 18 of word Osten.
#
# Surprisal score for actual word Osten. is 38.73095502281705.
# Text Nr = text_08 - Trial Nr = 76
#  ---------------
# computing probability for ID 1460 of word So
#
# Surprisal score for actual word So is 10.186112692115872.
# Text Nr = text_08 - Trial Nr = 77
#  ---------------
# computing probability for ID 734 of word reich
#
# Surprisal score for actual word reich is 12.786867312531799.
# Text Nr = text_08 - Trial Nr = 78
#  ---------------
# computing probability for ID 283 of word und
#
# Surprisal score for actual word und is 11.381469158065359.
# Text Nr = text_08 - Trial Nr = 79
#  ---------------
# computing probability for ID 25713 of word mächtig
#
# Surprisal score for actual word mächtig is 11.535176906571442.
# Text Nr = text_08 - Trial Nr = 80
#  ---------------
# computing probability for ID 35973 of word wurde
#
# Surprisal score for actual word wurde is 20.512875982786863.
# Text Nr = text_08 - Trial Nr = 81
#  ---------------
# computing probability for ID 5972 of word das
#
# Surprisal score for actual word das is 14.141230409925459.
# Text Nr = text_08 - Trial Nr = 82
#  ---------------
# computing probability for ID 59 of word Wüstenvolk,
# computing probability for ID 15741 of word Wüstenvolk,
# computing probability for ID 37604 of word Wüstenvolk,
# computing probability for ID 16 of word Wüstenvolk,
#
# Surprisal score for actual word Wüstenvolk, is 51.508790922470226.
# Text Nr = text_08 - Trial Nr = 83
#  ---------------
# computing probability for ID 5582 of word dass
#
# Surprisal score for actual word dass is 9.129117503904194.
# Text Nr = text_08 - Trial Nr = 84
#  ---------------
# computing probability for ID 271 of word es
#
# Surprisal score for actual word es is 16.185682705970454.
# Text Nr = text_08 - Trial Nr = 85
#  ---------------
# computing probability for ID 87 of word sogar
# computing probability for ID 17509 of word sogar
#
# Surprisal score for actual word sogar is 27.669687100969465.
# Text Nr = text_08 - Trial Nr = 86
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 13.415509019604837.
# Text Nr = text_08 - Trial Nr = 87
#  ---------------
# computing probability for ID 38400 of word Römer
# computing probability for ID 505 of word Römer
#
# Surprisal score for actual word Römer is 25.257969535974006.
# Text Nr = text_08 - Trial Nr = 88
#  ---------------
# computing probability for ID 29388 of word herausforderte.
# computing probability for ID 47475 of word herausforderte.
# computing probability for ID 18 of word herausforderte.
#
# Surprisal score for actual word herausforderte. is 32.57353721165538.
# Text Nr = text_08 - Trial Nr = 89
#  ---------------
# computing probability for ID 2537 of word Doch
#
# Surprisal score for actual word Doch is 11.891219771117662.
# Text Nr = text_08 - Trial Nr = 90
#  ---------------
# computing probability for ID 687 of word wie
#
# Surprisal score for actual word wie is 8.13867279700763.
# Text Nr = text_08 - Trial Nr = 91
#  ---------------
# computing probability for ID 44188 of word ihre
#
# Surprisal score for actual word ihre is 16.47374805659992.
# Text Nr = text_08 - Trial Nr = 92
#  ---------------
# computing probability for ID 5213 of word riesige
# computing probability for ID 595 of word riesige
#
# Surprisal score for actual word riesige is 25.615799799373736.
# Text Nr = text_08 - Trial Nr = 93
#  ---------------
# computing probability for ID 49192 of word Hauptstadt
#
# Surprisal score for actual word Hauptstadt is 22.61444844152247.
# Text Nr = text_08 - Trial Nr = 94
#  ---------------
# computing probability for ID 14857 of word mitten
#
# Surprisal score for actual word mitten is 12.609083905799169.
# Text Nr = text_08 - Trial Nr = 95
#  ---------------
# computing probability for ID 269 of word in
#
# Surprisal score for actual word in is 8.43461682448438.
# Text Nr = text_08 - Trial Nr = 96
#  ---------------
# computing probability for ID 320 of word der
#
# Surprisal score for actual word der is 12.677774858929164.
# Text Nr = text_08 - Trial Nr = 97
#  ---------------
# computing probability for ID 59 of word Wüste
# computing probability for ID 6211 of word Wüste
#
# Surprisal score for actual word Wüste is 27.670514959217478.
# Text Nr = text_08 - Trial Nr = 98
#  ---------------
# computing probability for ID 8325 of word funktioniert
# computing probability for ID 588 of word funktioniert
#
# Surprisal score for actual word funktioniert is 21.746053467009386.
# Text Nr = text_08 - Trial Nr = 99
#  ---------------
# computing probability for ID 8491 of word hat,
# computing probability for ID 16 of word hat,
#
# Surprisal score for actual word hat, is 26.109497024111853.
# Text Nr = text_08 - Trial Nr = 100
#  ---------------
# computing probability for ID 11359 of word weiß
#
# Surprisal score for actual word weiß is 13.788728330897467.
# Text Nr = text_08 - Trial Nr = 101
#  ---------------
# computing probability for ID 12049 of word niemand
# computing probability for ID 3872 of word niemand
#
# Surprisal score for actual word niemand is 27.561352137278142.
# Text Nr = text_08 - Trial Nr = 102
#  ---------------
# computing probability for ID 24709 of word genau.
# computing probability for ID 18 of word genau.
#
# Surprisal score for actual word genau. is 22.450083122300047.
# Text Nr = text_08 - Trial Nr = 103
#  ---------------
# computing probability for ID 10239 of word Sicher
#
# Surprisal score for actual word Sicher is 10.252117667917814.
# Text Nr = text_08 - Trial Nr = 104
#  ---------------
# computing probability for ID 510 of word ist,
# computing probability for ID 16 of word ist,
#
# Surprisal score for actual word ist, is 26.335560047516513.
# Text Nr = text_08 - Trial Nr = 105
#  ---------------
# computing probability for ID 5582 of word dass
#
# Surprisal score for actual word dass is 7.725492373865568.
# Text Nr = text_08 - Trial Nr = 106
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 12.512740984886864.
# Text Nr = text_08 - Trial Nr = 107
#  ---------------
# computing probability for ID 7526 of word Stadt
#
# Surprisal score for actual word Stadt is 17.34005707445514.
# Text Nr = text_08 - Trial Nr = 108
#  ---------------
# computing probability for ID 269 of word in
#
# Surprisal score for actual word in is 11.28746185562658.
# Text Nr = text_08 - Trial Nr = 109
#  ---------------
# computing probability for ID 895 of word atemberaubend
# computing probability for ID 81 of word atemberaubend
# computing probability for ID 331 of word atemberaubend
# computing probability for ID 399 of word atemberaubend
# computing probability for ID 2388 of word atemberaubend
#
# Surprisal score for actual word atemberaubend is 49.72168466925976.
# Text Nr = text_08 - Trial Nr = 110
#  ---------------
# computing probability for ID 22429 of word kurzer
# computing probability for ID 261 of word kurzer
#
# Surprisal score for actual word kurzer is 19.934050499782327.
# Text Nr = text_08 - Trial Nr = 111
#  ---------------
# computing probability for ID 6485 of word Zeit
#
# Surprisal score for actual word Zeit is 12.565259894905214.
# Text Nr = text_08 - Trial Nr = 112
#  ---------------
# computing probability for ID 384 of word entstand.
# computing probability for ID 1021 of word entstand.
# computing probability for ID 18 of word entstand.
#
# Surprisal score for actual word entstand. is 30.250622009984138.
# Text Nr = text_08 - Trial Nr = 113
#  ---------------
# computing probability for ID 1439 of word Als
#
# Surprisal score for actual word Als is 9.647599665348158.
# Text Nr = text_08 - Trial Nr = 114
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 9.838511958087997.
# Text Nr = text_08 - Trial Nr = 115
#  ---------------
# computing probability for ID 50 of word Nabatäer
# computing probability for ID 421 of word Nabatäer
# computing probability for ID 297 of word Nabatäer
# computing probability for ID 27031 of word Nabatäer
#
# Surprisal score for actual word Nabatäer is 59.39618921250361.
# Text Nr = text_08 - Trial Nr = 116
#  ---------------
# computing probability for ID 2541 of word ins
#
# Surprisal score for actual word ins is 13.41889641152139.
# Text Nr = text_08 - Trial Nr = 117
#  ---------------
# computing probability for ID 31728 of word heutige
# computing probability for ID 1097 of word heutige
#
# Surprisal score for actual word heutige is 22.793837762820942.
# Text Nr = text_08 - Trial Nr = 118
#  ---------------
# computing probability for ID 46 of word Jordanien
# computing probability for ID 635 of word Jordanien
# computing probability for ID 2924 of word Jordanien
#
# Surprisal score for actual word Jordanien is 39.29498360336226.
# Text Nr = text_08 - Trial Nr = 119
#  ---------------
# computing probability for ID 90 of word vordrangen,
# computing probability for ID 635 of word vordrangen,
# computing probability for ID 34390 of word vordrangen,
# computing probability for ID 16 of word vordrangen,
#
# Surprisal score for actual word vordrangen, is 32.503205143950126.
# Text Nr = text_08 - Trial Nr = 120
#  ---------------
# computing probability for ID 982 of word war
#
# Surprisal score for actual word war is 9.96719698840464.
# Text Nr = text_08 - Trial Nr = 121
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 12.393074545503426.
# Text Nr = text_08 - Trial Nr = 122
#  ---------------
# computing probability for ID 11820 of word Region
#
# Surprisal score for actual word Region is 19.423679543520112.
# Text Nr = text_08 - Trial Nr = 123
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 12.631369743743573.
# Text Nr = text_08 - Trial Nr = 124
#  ---------------
# computing probability for ID 8883 of word reinste
# computing probability for ID 397 of word reinste
#
# Surprisal score for actual word reinste is 25.19280901969084.
# Text Nr = text_08 - Trial Nr = 125
#  ---------------
# computing probability for ID 16622 of word Goldgrube.
# computing probability for ID 27866 of word Goldgrube.
# computing probability for ID 18 of word Goldgrube.
#
# Surprisal score for actual word Goldgrube. is 33.96309369362193.
# Text Nr = text_08 - Trial Nr = 126
#  ---------------
# computing probability for ID 1409 of word Bei
#
# Surprisal score for actual word Bei is 9.158910589734955.
# Text Nr = text_08 - Trial Nr = 127
#  ---------------
# computing probability for ID 52 of word Petra
# computing probability for ID 19266 of word Petra
#
# Surprisal score for actual word Petra is 26.737400302278044.
# Text Nr = text_08 - Trial Nr = 128
#  ---------------
# computing probability for ID 9813 of word kreuzten
# computing probability for ID 310 of word kreuzten
#
# Surprisal score for actual word kreuzten is 25.24314242374359.
# Text Nr = text_08 - Trial Nr = 129
#  ---------------
# computing probability for ID 12592 of word sich
#
# Surprisal score for actual word sich is 10.889847393493556.
# Text Nr = text_08 - Trial Nr = 130
#  ---------------
# computing probability for ID 4262 of word mehrere
# computing probability for ID 1261 of word mehrere
#
# Surprisal score for actual word mehrere is 21.93311973879422.
# Text Nr = text_08 - Trial Nr = 131
#  ---------------
# computing probability for ID 19999 of word Handelswege,
# computing probability for ID 8109 of word Handelswege,
# computing probability for ID 16 of word Handelswege,
#
# Surprisal score for actual word Handelswege, is 28.818562013280232.
# Text Nr = text_08 - Trial Nr = 132
#  ---------------
# computing probability for ID 40869 of word darunter
#
# Surprisal score for actual word darunter is 10.86576270708864.
# Text Nr = text_08 - Trial Nr = 133
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 12.277949833774919.
# Text Nr = text_08 - Trial Nr = 134
#  ---------------
# computing probability for ID 294 of word uralte
# computing probability for ID 7512 of word uralte
#
# Surprisal score for actual word uralte is 28.649547725736085.
# Text Nr = text_08 - Trial Nr = 135
#  ---------------
# computing probability for ID 12408 of word Weihrauchstraße.
# computing probability for ID 302 of word Weihrauchstraße.
# computing probability for ID 4564 of word Weihrauchstraße.
# computing probability for ID 1926 of word Weihrauchstraße.
# computing probability for ID 18 of word Weihrauchstraße.
#
# Surprisal score for actual word Weihrauchstraße. is 55.332957948457135.
# Text Nr = text_08 - Trial Nr = 136
#  ---------------
# computing probability for ID 32080 of word Binnen
#
# Surprisal score for actual word Binnen is 15.143279669653916.
# Text Nr = text_08 - Trial Nr = 137
#  ---------------
# computing probability for ID 43539 of word weniger
#
# Surprisal score for actual word weniger is 15.92994398342301.
# Text Nr = text_08 - Trial Nr = 138
#  ---------------
# computing probability for ID 3998 of word Jahrzehnte
# computing probability for ID 94 of word Jahrzehnte
# computing probability for ID 7081 of word Jahrzehnte
#
# Surprisal score for actual word Jahrzehnte is 31.36395168220474.
# Text Nr = text_08 - Trial Nr = 139
#  ---------------
# computing probability for ID 384 of word entstanden
# computing probability for ID 7692 of word entstanden
#
# Surprisal score for actual word entstanden is 25.592879088080572.
# Text Nr = text_08 - Trial Nr = 140
#  ---------------
# computing probability for ID 1544 of word hunderte
# computing probability for ID 7963 of word hunderte
#
# Surprisal score for actual word hunderte is 15.338676597829748.
# Text Nr = text_08 - Trial Nr = 141
#  ---------------
# computing probability for ID 11387 of word Höhlen
# computing probability for ID 4417 of word Höhlen
#
# Surprisal score for actual word Höhlen is 32.986255757783184.
# Text Nr = text_08 - Trial Nr = 142
#  ---------------
# computing probability for ID 774 of word mit
#
# Surprisal score for actual word mit is 12.198559255166392.
# Text Nr = text_08 - Trial Nr = 143
#  ---------------
# computing probability for ID 987 of word prunkvollen
# computing probability for ID 3053 of word prunkvollen
# computing probability for ID 7661 of word prunkvollen
#
# Surprisal score for actual word prunkvollen is 39.07797814355239.
# Text Nr = text_08 - Trial Nr = 144
#  ---------------
# computing probability for ID 48759 of word Fassaden
# computing probability for ID 1578 of word Fassaden
#
# Surprisal score for actual word Fassaden is 21.28823821464767.
# Text Nr = text_08 - Trial Nr = 145
#  ---------------
# computing probability for ID 283 of word und
#
# Surprisal score for actual word und is 9.572145398713015.
# Text Nr = text_08 - Trial Nr = 146
#  ---------------
# computing probability for ID 8591 of word teils
#
# Surprisal score for actual word teils is 11.566533991800211.
# Text Nr = text_08 - Trial Nr = 147
#  ---------------
# computing probability for ID 12799 of word gewaltigen
# computing probability for ID 937 of word gewaltigen
#
# Surprisal score for actual word gewaltigen is 20.037282909781357.
# Text Nr = text_08 - Trial Nr = 148
#  ---------------
# computing probability for ID 54 of word Räumen.
# computing probability for ID 23657 of word Räumen.
# computing probability for ID 18 of word Räumen.
#
# Surprisal score for actual word Räumen. is 36.94717330267719.
# Text Nr = text_08 - Trial Nr = 149
#  ---------------
# computing probability for ID 1870 of word Von
#
# Surprisal score for actual word Von is 8.24692863650167.
# Text Nr = text_08 - Trial Nr = 150
#  ---------------
# computing probability for ID 320 of word der
#
# Surprisal score for actual word der is 8.840951340159359.
# Text Nr = text_08 - Trial Nr = 151
#  ---------------
# computing probability for ID 802 of word eigentlichen
# computing probability for ID 6539 of word eigentlichen
#
# Surprisal score for actual word eigentlichen is 33.72493930481831.
# Text Nr = text_08 - Trial Nr = 152
#  ---------------
# computing probability for ID 7526 of word Stadt
#
# Surprisal score for actual word Stadt is 18.393770496600798.
# Text Nr = text_08 - Trial Nr = 153
#  ---------------
# computing probability for ID 510 of word ist
#
# Surprisal score for actual word ist is 14.740806550717222.
# Text Nr = text_08 - Trial Nr = 154
#  ---------------
# computing probability for ID 11074 of word heute
#
# Surprisal score for actual word heute is 12.309323001797956.
# Text Nr = text_08 - Trial Nr = 155
#  ---------------
# computing probability for ID 82 of word nichts
# computing probability for ID 1701 of word nichts
#
# Surprisal score for actual word nichts is 28.611363684610666.
# Text Nr = text_08 - Trial Nr = 156
#  ---------------
# computing probability for ID 29747 of word geblieben
#
# Surprisal score for actual word geblieben is 11.626272598434202.
# Text Nr = text_08 - Trial Nr = 157
#  ---------------
# computing probability for ID 25017 of word außer
#
# Surprisal score for actual word außer is 15.140181618396467.
# Text Nr = text_08 - Trial Nr = 158
#  ---------------
# computing probability for ID 16991 of word Steinhaufen
# computing probability for ID 28687 of word Steinhaufen
#
# Surprisal score for actual word Steinhaufen is 28.66269510606042.
# Text Nr = text_08 - Trial Nr = 159
#  ---------------
# computing probability for ID 283 of word und
#
# Surprisal score for actual word und is 7.704194686263896.
# Text Nr = text_08 - Trial Nr = 160
#  ---------------
# computing probability for ID 49 of word Mauerreste.
# computing probability for ID 1289 of word Mauerreste.
# computing probability for ID 15064 of word Mauerreste.
# computing probability for ID 18 of word Mauerreste.
#
# Surprisal score for actual word Mauerreste. is 34.64999949152598.
# Text Nr = text_08 - Trial Nr = 161
#  ---------------
# computing probability for ID 3281 of word Bis
#
# Surprisal score for actual word Bis is 9.713114868938588.
# Text Nr = text_08 - Trial Nr = 162
#  ---------------
# computing probability for ID 269 of word in
#
# Surprisal score for actual word in is 12.015666129943341.
# Text Nr = text_08 - Trial Nr = 163
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 12.56154893077513.
# Text Nr = text_08 - Trial Nr = 164
#  ---------------
# computing probability for ID 2682 of word siebziger
# computing probability for ID 70 of word siebziger
# computing probability for ID 7419 of word siebziger
#
# Surprisal score for actual word siebziger is 40.80345020323304.
# Text Nr = text_08 - Trial Nr = 165
#  ---------------
# computing probability for ID 10800 of word Jahre
#
# Surprisal score for actual word Jahre is 10.06975368250234.
# Text Nr = text_08 - Trial Nr = 166
#  ---------------
# computing probability for ID 31168 of word glaubte
# computing probability for ID 280 of word glaubte
#
# Surprisal score for actual word glaubte is 21.972669950123134.
# Text Nr = text_08 - Trial Nr = 167
#  ---------------
# computing probability for ID 1473 of word man
#
# Surprisal score for actual word man is 15.019908321757825.
# Text Nr = text_08 - Trial Nr = 168
#  ---------------
# computing probability for ID 72 of word daher,
# computing probability for ID 5558 of word daher,
# computing probability for ID 16 of word daher,
#
# Surprisal score for actual word daher, is 34.08413340602406.
# Text Nr = text_08 - Trial Nr = 169
#  ---------------
# computing probability for ID 52 of word Petra
# computing probability for ID 19266 of word Petra
#
# Surprisal score for actual word Petra is 28.93879478313367.
# Text Nr = text_08 - Trial Nr = 170
#  ---------------
# computing probability for ID 3937 of word sei
#
# Surprisal score for actual word sei is 17.51378753261067.
# Text Nr = text_08 - Trial Nr = 171
#  ---------------
# computing probability for ID 580 of word eine
#
# Surprisal score for actual word eine is 12.882508333080095.
# Text Nr = text_08 - Trial Nr = 172
#  ---------------
# computing probability for ID 7526 of word Stadt
#
# Surprisal score for actual word Stadt is 20.42581102983507.
# Text Nr = text_08 - Trial Nr = 173
#  ---------------
# computing probability for ID 3658 of word für
#
# Surprisal score for actual word für is 7.76527903428555.
# Text Nr = text_08 - Trial Nr = 174
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 9.411280848836945.
# Text Nr = text_08 - Trial Nr = 175
#  ---------------
# computing probability for ID 56 of word Toten
# computing probability for ID 1419 of word Toten
#
# Surprisal score for actual word Toten is 27.074740938487043.
# Text Nr = text_08 - Trial Nr = 176
#  ---------------
# computing probability for ID 283 of word und
#
# Surprisal score for actual word und is 9.079416128993849.
# Text Nr = text_08 - Trial Nr = 177
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 11.987210349500021.
# Text Nr = text_08 - Trial Nr = 178
#  ---------------
# computing probability for ID 43 of word Götter
# computing probability for ID 32915 of word Götter
#
# Surprisal score for actual word Götter is 31.66909437189937.
# Text Nr = text_08 - Trial Nr = 179
#  ---------------
# computing probability for ID 1436 of word gewesen,
# computing probability for ID 1132 of word gewesen,
# computing probability for ID 16 of word gewesen,
#
# Surprisal score for actual word gewesen, is 27.13654121833315.
# Text Nr = text_08 - Trial Nr = 180
#  ---------------
# computing probability for ID 283 of word und
#
# Surprisal score for actual word und is 11.059570052334102.
# Text Nr = text_08 - Trial Nr = 181
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 11.914949336636377.
# Text Nr = text_08 - Trial Nr = 182
#  ---------------
# computing probability for ID 14527 of word Menschen
#
# Surprisal score for actual word Menschen is 18.855505842308872.
# Text Nr = text_08 - Trial Nr = 183
#  ---------------
# computing probability for ID 76 of word hätten
# computing probability for ID 14831 of word hätten
#
# Surprisal score for actual word hätten is 20.670855949277904.
# Text Nr = text_08 - Trial Nr = 184
#  ---------------
# computing probability for ID 3164 of word woanders
# computing probability for ID 14679 of word woanders
#
# Surprisal score for actual word woanders is 27.739866459592072.
# Text Nr = text_08 - Trial Nr = 185
#  ---------------
# computing probability for ID 1436 of word gewohnt.
# computing probability for ID 8523 of word gewohnt.
# computing probability for ID 18 of word gewohnt.
#
# Surprisal score for actual word gewohnt. is 40.10772761751691.
# Text Nr = text_08 - Trial Nr = 186
#  ---------------
# computing probability for ID 1385 of word Aber
#
# Surprisal score for actual word Aber is 10.589795299199427.
# Text Nr = text_08 - Trial Nr = 187
#  ---------------
# computing probability for ID 52 of word Petra
# computing probability for ID 19266 of word Petra
#
# Surprisal score for actual word Petra is 29.07837168811778.
# Text Nr = text_08 - Trial Nr = 188
#  ---------------
# computing probability for ID 982 of word war
#
# Surprisal score for actual word war is 14.79953675203575.
# Text Nr = text_08 - Trial Nr = 189
#  ---------------
# computing probability for ID 580 of word eine
#
# Surprisal score for actual word eine is 11.199132502791436.
# Text Nr = text_08 - Trial Nr = 190
#  ---------------
# computing probability for ID 21284 of word ganz
#
# Surprisal score for actual word ganz is 18.52484453004014.
# Text Nr = text_08 - Trial Nr = 191
#  ---------------
# computing probability for ID 12123 of word normale
# computing probability for ID 4538 of word normale
#
# Surprisal score for actual word normale is 20.5970575234656.
# Text Nr = text_08 - Trial Nr = 192
#  ---------------
# computing probability for ID 7526 of word Stadt,
# computing probability for ID 16 of word Stadt,
#
# Surprisal score for actual word Stadt, is 28.59620299078157.
# Text Nr = text_08 - Trial Nr = 193
#  ---------------
# computing probability for ID 12317 of word nur
#
# Surprisal score for actual word nur is 8.27260135150641.
# Text Nr = text_08 - Trial Nr = 194
#  ---------------
# computing probability for ID 270 of word an
#
# Surprisal score for actual word an is 15.82275496764595.
# Text Nr = text_08 - Trial Nr = 195
#  ---------------
# computing probability for ID 19875 of word einem
#
# Surprisal score for actual word einem is 16.107277028707493.
# Text Nr = text_08 - Trial Nr = 196
#  ---------------
# computing probability for ID 267 of word unmöglichen
# computing probability for ID 6280 of word unmöglichen
#
# Surprisal score for actual word unmöglichen is 34.53229140429525.
# Text Nr = text_08 - Trial Nr = 197
#  ---------------
# computing probability for ID 11462 of word Ort.
# computing probability for ID 18 of word Ort.
#
# Surprisal score for actual word Ort. is 26.07761421233284.
# Text Nr = text_08 - Trial Nr = 198
#  ---------------
# computing probability for ID 425 of word Die
#
# Surprisal score for actual word Die is 5.836189404579895.
# Text Nr = text_08 - Trial Nr = 199
#  ---------------
# computing probability for ID 918 of word seltenen
# computing probability for ID 310 of word seltenen
# computing probability for ID 262 of word seltenen
#
# Surprisal score for actual word seltenen is 35.75071485380878.
# Text Nr = text_08 - Trial Nr = 200
#  ---------------
# computing probability for ID 22459 of word Regenfälle
# computing probability for ID 4685 of word Regenfälle
#
# Surprisal score for actual word Regenfälle is 25.26524518233995.
# Text Nr = text_08 - Trial Nr = 201
#  ---------------
# computing probability for ID 82 of word nutzten
# computing probability for ID 15836 of word nutzten
#
# Surprisal score for actual word nutzten is 20.77464354597186.
# Text Nr = text_08 - Trial Nr = 202
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 13.543462174042759.
# Text Nr = text_08 - Trial Nr = 203
#  ---------------
# computing probability for ID 50 of word Nabatäer
# computing probability for ID 421 of word Nabatäer
# computing probability for ID 297 of word Nabatäer
# computing probability for ID 27031 of word Nabatäer
#
# Surprisal score for actual word Nabatäer is 57.797523513392406.
# Text Nr = text_08 - Trial Nr = 204
#  ---------------
# computing probability for ID 774 of word mit
#
# Surprisal score for actual word mit is 15.14225427398354.
# Text Nr = text_08 - Trial Nr = 205
#  ---------------
# computing probability for ID 19875 of word einem
#
# Surprisal score for actual word einem is 17.824635468178315.
# Text Nr = text_08 - Trial Nr = 206
#  ---------------
# computing probability for ID 312 of word genialen
# computing probability for ID 10768 of word genialen
#
# Surprisal score for actual word genialen is 28.674538452571692.
# Text Nr = text_08 - Trial Nr = 207
#  ---------------
# computing probability for ID 10644 of word Bewässerungssystem.
# computing probability for ID 5447 of word Bewässerungssystem.
# computing probability for ID 26668 of word Bewässerungssystem.
# computing probability for ID 18 of word Bewässerungssystem.
#
# Surprisal score for actual word Bewässerungssystem. is 41.86084190399993.
# Text Nr = text_08 - Trial Nr = 208
#  ---------------
# computing probability for ID 34013 of word Überall
#
# Surprisal score for actual word Überall is 12.743345113205072.
# Text Nr = text_08 - Trial Nr = 209
#  ---------------
# computing probability for ID 269 of word in
#
# Surprisal score for actual word in is 8.574537257429347.
# Text Nr = text_08 - Trial Nr = 210
#  ---------------
# computing probability for ID 320 of word der
#
# Surprisal score for actual word der is 12.021858822115203.
# Text Nr = text_08 - Trial Nr = 211
#  ---------------
# computing probability for ID 7526 of word Stadt
#
# Surprisal score for actual word Stadt is 15.184706886888305.
# Text Nr = text_08 - Trial Nr = 212
#  ---------------
# computing probability for ID 6957 of word waren
#
# Surprisal score for actual word waren is 10.129859310543857.
# Text Nr = text_08 - Trial Nr = 213
#  ---------------
# computing probability for ID 12572 of word Wasserbecken
# computing probability for ID 10229 of word Wasserbecken
#
# Surprisal score for actual word Wasserbecken is 33.381575641777836.
# Text Nr = text_08 - Trial Nr = 214
#  ---------------
# computing probability for ID 269 of word in
#
# Surprisal score for actual word in is 5.8182097962839.
# Text Nr = text_08 - Trial Nr = 215
#  ---------------
# computing probability for ID 324 of word den
#
# Surprisal score for actual word den is 14.591755427762395.
# Text Nr = text_08 - Trial Nr = 216
#  ---------------
# computing probability for ID 42 of word Fels
# computing probability for ID 1906 of word Fels
#
# Surprisal score for actual word Fels is 32.468630057354325.
# Text Nr = text_08 - Trial Nr = 217
#  ---------------
# computing probability for ID 5154 of word geschlagen.
# computing probability for ID 18 of word geschlagen.
#
# Surprisal score for actual word geschlagen. is 23.463892398703344.
# Text Nr = text_08 - Trial Nr = 218
#  ---------------
# computing probability for ID 5516 of word Viele
#
# Surprisal score for actual word Viele is 10.052450205150082.
# Text Nr = text_08 - Trial Nr = 219
#  ---------------
# computing probability for ID 18267 of word Kilometer
#
# Surprisal score for actual word Kilometer is 13.470877024603041.
# Text Nr = text_08 - Trial Nr = 220
#  ---------------
# computing probability for ID 12572 of word Wasserleitungen
# computing probability for ID 14446 of word Wasserleitungen
#
# Surprisal score for actual word Wasserleitungen is 20.328379542873602.
# Text Nr = text_08 - Trial Nr = 221
#  ---------------
# computing probability for ID 42665 of word leiteten
#
# Surprisal score for actual word leiteten is 23.374707258669254.
# Text Nr = text_08 - Trial Nr = 222
#  ---------------
# computing probability for ID 5972 of word das
#
# Surprisal score for actual word das is 12.210271241817662.
# Text Nr = text_08 - Trial Nr = 223
#  ---------------
# computing probability for ID 12572 of word Wasser
#
# Surprisal score for actual word Wasser is 18.021723345445242.
# Text Nr = text_08 - Trial Nr = 224
#  ---------------
# computing probability for ID 636 of word zuerst
# computing probability for ID 1992 of word zuerst
#
# Surprisal score for actual word zuerst is 18.292962205266374.
# Text Nr = text_08 - Trial Nr = 225
#  ---------------
# computing probability for ID 269 of word in
#
# Surprisal score for actual word in is 14.794875122282392.
# Text Nr = text_08 - Trial Nr = 226
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 11.611507065346245.
# Text Nr = text_08 - Trial Nr = 227
#  ---------------
# computing probability for ID 46342 of word Speicher
#
# Surprisal score for actual word Speicher is 21.61123907427807.
# Text Nr = text_08 - Trial Nr = 228
#  ---------------
# computing probability for ID 283 of word und
#
# Surprisal score for actual word und is 10.104340593044473.
# Text Nr = text_08 - Trial Nr = 229
#  ---------------
# computing probability for ID 1420 of word von
#
# Surprisal score for actual word von is 12.981126371607951.
# Text Nr = text_08 - Trial Nr = 230
#  ---------------
# computing probability for ID 72 of word dort
# computing probability for ID 503 of word dort
#
# Surprisal score for actual word dort is 22.98699140872854.
# Text Nr = text_08 - Trial Nr = 231
#  ---------------
# computing probability for ID 481 of word aus
#
# Surprisal score for actual word aus is 12.407744422501791.
# Text Nr = text_08 - Trial Nr = 232
#  ---------------
# computing probability for ID 636 of word zu
#
# Surprisal score for actual word zu is 13.1087157199327.
# Text Nr = text_08 - Trial Nr = 233
#  ---------------
# computing probability for ID 324 of word den
#
# Surprisal score for actual word den is 12.185375778859193.
# Text Nr = text_08 - Trial Nr = 234
#  ---------------
# computing probability for ID 10644 of word Bewohnern.
# computing probability for ID 694 of word Bewohnern.
# computing probability for ID 470 of word Bewohnern.
# computing probability for ID 18 of word Bewohnern.
#
# Surprisal score for actual word Bewohnern. is 55.50748579376356.
# Text Nr = text_08 - Trial Nr = 235
#  ---------------
# computing probability for ID 425 of word Die
#
# Surprisal score for actual word Die is 5.542188094942683.
# Text Nr = text_08 - Trial Nr = 236
#  ---------------
# computing probability for ID 90 of word vielen
# computing probability for ID 3891 of word vielen
#
# Surprisal score for actual word vielen is 21.788690150068973.
# Text Nr = text_08 - Trial Nr = 237
#  ---------------
# computing probability for ID 24106 of word Leitungen,
# computing probability for ID 429 of word Leitungen,
# computing probability for ID 16 of word Leitungen,
#
# Surprisal score for actual word Leitungen, is 38.33741578138493.
# Text Nr = text_08 - Trial Nr = 238
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 7.132485690638906.
# Text Nr = text_08 - Trial Nr = 239
#  ---------------
# computing probability for ID 324 of word den
#
# Surprisal score for actual word den is 20.2023547352491.
# Text Nr = text_08 - Trial Nr = 240
#  ---------------
# computing probability for ID 22459 of word Regen
#
# Surprisal score for actual word Regen is 20.09134954710004.
# Text Nr = text_08 - Trial Nr = 241
#  ---------------
# computing probability for ID 42850 of word einst
#
# Surprisal score for actual word einst is 17.106029706381957.
# Text Nr = text_08 - Trial Nr = 242
#  ---------------
# computing probability for ID 1420 of word von
#
# Surprisal score for actual word von is 14.229350421367062.
# Text Nr = text_08 - Trial Nr = 243
#  ---------------
# computing probability for ID 324 of word den
#
# Surprisal score for actual word den is 14.187504710405243.
# Text Nr = text_08 - Trial Nr = 244
#  ---------------
# computing probability for ID 1729 of word wertvollen
# computing probability for ID 7661 of word wertvollen
#
# Surprisal score for actual word wertvollen is 32.082058330682635.
# Text Nr = text_08 - Trial Nr = 245
#  ---------------
# computing probability for ID 48759 of word Fassaden
# computing probability for ID 1578 of word Fassaden
#
# Surprisal score for actual word Fassaden is 27.352942909989878.
# Text Nr = text_08 - Trial Nr = 246
#  ---------------
# computing probability for ID 1694 of word fernhielten,
# computing probability for ID 23128 of word fernhielten,
# computing probability for ID 16 of word fernhielten,
#
# Surprisal score for actual word fernhielten, is 30.298304958467426.
# Text Nr = text_08 - Trial Nr = 247
#  ---------------
# computing probability for ID 9428 of word wurden
# computing probability for ID 324 of word wurden
#
# Surprisal score for actual word wurden is 20.603394818708697.
# Text Nr = text_08 - Trial Nr = 248
#  ---------------
# computing probability for ID 1420 of word von
#
# Surprisal score for actual word von is 13.555933133245494.
# Text Nr = text_08 - Trial Nr = 249
#  ---------------
# computing probability for ID 324 of word den
#
# Surprisal score for actual word den is 18.12273918003975.
# Text Nr = text_08 - Trial Nr = 250
#  ---------------
# computing probability for ID 50 of word Nabatäern
# computing probability for ID 421 of word Nabatäern
# computing probability for ID 297 of word Nabatäern
# computing probability for ID 284 of word Nabatäern
# computing probability for ID 470 of word Nabatäern
#
# Surprisal score for actual word Nabatäern is 67.46908327322045.
# Text Nr = text_08 - Trial Nr = 251
#  ---------------
# computing probability for ID 35160 of word dauernd
# computing probability for ID 72 of word dauernd
#
# Surprisal score for actual word dauernd is 18.551073644502342.
# Text Nr = text_08 - Trial Nr = 252
#  ---------------
# computing probability for ID 269 of word instand
# computing probability for ID 1021 of word instand
#
# Surprisal score for actual word instand is 17.178897677102842.
# Text Nr = text_08 - Trial Nr = 253
#  ---------------
# computing probability for ID 28301 of word gehalten.
# computing probability for ID 18 of word gehalten.
#
# Surprisal score for actual word gehalten. is 14.596004436736926.
# Text Nr = text_08 - Trial Nr = 254
#  ---------------
# computing probability for ID 2537 of word Doch
#
# Surprisal score for actual word Doch is 11.763469950939214.
# Text Nr = text_08 - Trial Nr = 255
#  ---------------
# computing probability for ID 17885 of word wenn
#
# Surprisal score for actual word wenn is 11.598593206410088.
# Text Nr = text_08 - Trial Nr = 256
#  ---------------
# computing probability for ID 271 of word es
#
# Surprisal score for actual word es is 8.862998493717766.
# Text Nr = text_08 - Trial Nr = 257
#  ---------------
# computing probability for ID 27486 of word jetzt
#
# Surprisal score for actual word jetzt is 10.567320461719744.
# Text Nr = text_08 - Trial Nr = 258
#  ---------------
# computing probability for ID 1888 of word regnet,
# computing probability for ID 850 of word regnet,
# computing probability for ID 16 of word regnet,
#
# Surprisal score for actual word regnet, is 33.0735532453084.
# Text Nr = text_08 - Trial Nr = 259
#  ---------------
# computing probability for ID 19018 of word strömt
# computing probability for ID 88 of word strömt
#
# Surprisal score for actual word strömt is 17.33282112431212.
# Text Nr = text_08 - Trial Nr = 260
#  ---------------
# computing probability for ID 5972 of word das
#
# Surprisal score for actual word das is 14.596311913601342.
# Text Nr = text_08 - Trial Nr = 261
#  ---------------
# computing probability for ID 12572 of word Wasser
#
# Surprisal score for actual word Wasser is 16.243231710914742.
# Text Nr = text_08 - Trial Nr = 262
#  ---------------
# computing probability for ID 3053 of word unkontrolliert
# computing probability for ID 947 of word unkontrolliert
# computing probability for ID 9670 of word unkontrolliert
# computing probability for ID 588 of word unkontrolliert
#
# Surprisal score for actual word unkontrolliert is 40.27788281442829.
# Text Nr = text_08 - Trial Nr = 263
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 9.599419377059647.
# Text Nr = text_08 - Trial Nr = 264
#  ---------------
# computing probability for ID 48759 of word Fassaden
# computing probability for ID 1578 of word Fassaden
#
# Surprisal score for actual word Fassaden is 26.135844133917853.
# Text Nr = text_08 - Trial Nr = 265
#  ---------------
# computing probability for ID 621 of word herab.
# computing probability for ID 421 of word herab.
# computing probability for ID 18 of word herab.
#
# Surprisal score for actual word herab. is 40.323242817461654.
# Text Nr = text_08 - Trial Nr = 266
#  ---------------
# computing probability for ID 1512 of word Für
#
# Surprisal score for actual word Für is 7.734800430437671.
# Text Nr = text_08 - Trial Nr = 267
#  ---------------
# computing probability for ID 324 of word den
#
# Surprisal score for actual word den is 11.847392238768714.
# Text Nr = text_08 - Trial Nr = 268
#  ---------------
# computing probability for ID 20672 of word Sandstein
# computing probability for ID 1772 of word Sandstein
#
# Surprisal score for actual word Sandstein is 24.78755743211401.
# Text Nr = text_08 - Trial Nr = 269
#  ---------------
# computing probability for ID 510 of word ist
#
# Surprisal score for actual word ist is 13.283920653630906.
# Text Nr = text_08 - Trial Nr = 270
#  ---------------
# computing probability for ID 5972 of word das
#
# Surprisal score for actual word das is 12.038691571309062.
# Text Nr = text_08 - Trial Nr = 271
#  ---------------
# computing probability for ID 580 of word eine
#
# Surprisal score for actual word eine is 17.663025768675464.
# Text Nr = text_08 - Trial Nr = 272
#  ---------------
# computing probability for ID 11604 of word Katastrophe.
# computing probability for ID 8445 of word Katastrophe.
# computing probability for ID 462 of word Katastrophe.
# computing probability for ID 18 of word Katastrophe.
#
# Surprisal score for actual word Katastrophe. is 40.87295768167205.
# Text Nr = text_08 - Trial Nr = 273
#  ---------------
# computing probability for ID 5038 of word Versuche
# computing probability for ID 2221 of word Versuche
#
# Surprisal score for actual word Versuche is 21.035722930364027.
# Text Nr = text_08 - Trial Nr = 274
#  ---------------
# computing probability for ID 5230 of word zur
#
# Surprisal score for actual word zur is 12.716724687085984.
# Text Nr = text_08 - Trial Nr = 275
#  ---------------
# computing probability for ID 34198 of word Rettung
# computing probability for ID 288 of word Rettung
#
# Surprisal score for actual word Rettung is 22.230584497094554.
# Text Nr = text_08 - Trial Nr = 276
#  ---------------
# computing probability for ID 320 of word der
#
# Surprisal score for actual word der is 12.533923317642085.
# Text Nr = text_08 - Trial Nr = 277
#  ---------------
# computing probability for ID 48759 of word Fassaden
# computing probability for ID 1578 of word Fassaden
#
# Surprisal score for actual word Fassaden is 24.108795401248425.
# Text Nr = text_08 - Trial Nr = 278
#  ---------------
# computing probability for ID 10218 of word gab
#
# Surprisal score for actual word gab is 17.16800702207148.
# Text Nr = text_08 - Trial Nr = 279
#  ---------------
# computing probability for ID 271 of word es,
# computing probability for ID 16 of word es,
#
# Surprisal score for actual word es, is 20.517878978726515.
# Text Nr = text_08 - Trial Nr = 280
#  ---------------
# computing probability for ID 40937 of word doch
#
# Surprisal score for actual word doch is 10.504741809601459.
# Text Nr = text_08 - Trial Nr = 281
#  ---------------
# computing probability for ID 2895 of word wirklich
# computing probability for ID 341 of word wirklich
#
# Surprisal score for actual word wirklich is 16.04283120202453.
# Text Nr = text_08 - Trial Nr = 282
#  ---------------
# computing probability for ID 27013 of word erfolgreich
# computing probability for ID 734 of word erfolgreich
#
# Surprisal score for actual word erfolgreich is 22.962093581923643.
# Text Nr = text_08 - Trial Nr = 283
#  ---------------
# computing probability for ID 982 of word war
#
# Surprisal score for actual word war is 12.485663293650285.
# Text Nr = text_08 - Trial Nr = 284
#  ---------------
# computing probability for ID 5644 of word bislang
# computing probability for ID 2445 of word bislang
#
# Surprisal score for actual word bislang is 22.476930365435532.
# Text Nr = text_08 - Trial Nr = 285
#  ---------------
# computing probability for ID 689 of word leider
# computing probability for ID 320 of word leider
#
# Surprisal score for actual word leider is 25.273705160939187.
# Text Nr = text_08 - Trial Nr = 286
#  ---------------
# computing probability for ID 79 of word keiner.
# computing probability for ID 2276 of word keiner.
# computing probability for ID 18 of word keiner.
#
# Surprisal score for actual word keiner. is 30.820941086485377.
# Text Nr = text_08 - Trial Nr = 287
#  ---------------
# computing probability for ID 425 of word Die
#
# Surprisal score for actual word Die is 6.803770946378456.
# Text Nr = text_08 - Trial Nr = 288
#  ---------------
# computing probability for ID 15249 of word antike
# computing probability for ID 695 of word antike
#
# ...
# computing probability for ID 1694 of word entfernt
# computing probability for ID 88 of word entfernt
#
# Surprisal score for actual word entfernt is 31.494385459028955.
# Text Nr = text_09 - Trial Nr = 51
#  ---------------
# computing probability for ID 487 of word im
#
# Surprisal score for actual word im is 12.302807797577433.
# Text Nr = text_09 - Trial Nr = 52
#  ---------------
# computing probability for ID 30391 of word Dorf
#
# Surprisal score for actual word Dorf is 15.6081603380702.
# Text Nr = text_09 - Trial Nr = 53
#  ---------------
# computing probability for ID 864 of word Stratford-upon-Avon
# computing probability for ID 844 of word Stratford-upon-Avon
# computing probability for ID 6522 of word Stratford-upon-Avon
# computing probability for ID 17 of word Stratford-upon-Avon
# computing probability for ID 1768 of word Stratford-upon-Avon
# computing probability for ID 274 of word Stratford-upon-Avon
# computing probability for ID 17 of word Stratford-upon-Avon
# computing probability for ID 37 of word Stratford-upon-Avon
# computing probability for ID 1420 of word Stratford-upon-Avon
#
# Surprisal score for actual word Stratford-upon-Avon is 90.61123868519039.
# Text Nr = text_09 - Trial Nr = 54
#  ---------------
# computing probability for ID 587 of word aufwuchs,
# computing probability for ID 7609 of word aufwuchs,
# computing probability for ID 16 of word aufwuchs,
#
# Surprisal score for actual word aufwuchs, is 27.47843511407741.
# Text Nr = text_09 - Trial Nr = 55
#  ---------------
# computing probability for ID 87 of word sollte
# computing probability for ID 31252 of word sollte
#
# Surprisal score for actual word sollte is 17.85614875471275.
# Text Nr = text_09 - Trial Nr = 56
#  ---------------
# computing probability for ID 27727 of word später
#
# Surprisal score for actual word später is 19.48716855817497.
# Text Nr = text_09 - Trial Nr = 57
#  ---------------
# computing probability for ID 7418 of word zum
#
# Surprisal score for actual word zum is 13.157882030230507.
# Text Nr = text_09 - Trial Nr = 58
#  ---------------
# computing probability for ID 29723 of word größten
#
# Surprisal score for actual word größten is 18.222843640358054.
# Text Nr = text_09 - Trial Nr = 59
#  ---------------
# computing probability for ID 40 of word Dramatiker
# computing probability for ID 3372 of word Dramatiker
# computing probability for ID 33219 of word Dramatiker
#
# Surprisal score for actual word Dramatiker is 34.32007906601975.
# Text Nr = text_09 - Trial Nr = 60
#  ---------------
# computing probability for ID 6204 of word aller
#
# Surprisal score for actual word aller is 13.251544634000357.
# Text Nr = text_09 - Trial Nr = 61
#  ---------------
# computing probability for ID 40571 of word Zeiten
#
# Surprisal score for actual word Zeiten is 20.31298154861335.
# Text Nr = text_09 - Trial Nr = 62
#  ---------------
# computing probability for ID 621 of word heranwachsen.
# computing probability for ID 270 of word heranwachsen.
# computing probability for ID 11262 of word heranwachsen.
# computing probability for ID 18 of word heranwachsen.
#
# Surprisal score for actual word heranwachsen. is 35.68226871057226.
# Text Nr = text_09 - Trial Nr = 63
#  ---------------
# computing probability for ID 38460 of word Forscher
#
# Surprisal score for actual word Forscher is 12.257137296484583.
# Text Nr = text_09 - Trial Nr = 64
#  ---------------
# computing probability for ID 320 of word der
#
# Surprisal score for actual word der is 8.762088177348293.
# Text Nr = text_09 - Trial Nr = 65
#  ---------------
# computing probability for ID 7849 of word Universität
#
# Surprisal score for actual word Universität is 15.713060241294011.
# Text Nr = text_09 - Trial Nr = 66
#  ---------------
# computing probability for ID 1420 of word von
#
# Surprisal score for actual word von is 9.0126107776619.
# Text Nr = text_09 - Trial Nr = 67
#  ---------------
# computing probability for ID 46560 of word Oxford
# computing probability for ID 6522 of word Oxford
#
# Surprisal score for actual word Oxford is 20.559500033663568.
# Text Nr = text_09 - Trial Nr = 68
#  ---------------
# computing probability for ID 26702 of word vermuten
# computing probability for ID 1155 of word vermuten
#
# Surprisal score for actual word vermuten is 40.47906261548243.
# Text Nr = text_09 - Trial Nr = 69
#  ---------------
# computing probability for ID 49734 of word nun
#
# Surprisal score for actual word nun is 20.50254399797972.
# Text Nr = text_09 - Trial Nr = 70
#  ---------------
# computing probability for ID 946 of word einen
#
# Surprisal score for actual word einen is 14.991183263211356.
# Text Nr = text_09 - Trial Nr = 71
#  ---------------
# computing probability for ID 8981 of word Zusammenhang
# computing probability for ID 2514 of word Zusammenhang
#
# Surprisal score for actual word Zusammenhang is 25.0530441170587.
# Text Nr = text_09 - Trial Nr = 72
#  ---------------
# computing probability for ID 14909 of word dieses
# computing probability for ID 271 of word dieses
#
# Surprisal score for actual word dieses is 13.563757864445982.
# Text Nr = text_09 - Trial Nr = 73
#  ---------------
# computing probability for ID 697 of word Unfalls
# computing probability for ID 1511 of word Unfalls
#
# Surprisal score for actual word Unfalls is 23.82269628750581.
# Text Nr = text_09 - Trial Nr = 74
#  ---------------
# computing probability for ID 774 of word mit
#
# Surprisal score for actual word mit is 9.612904391321711.
# Text Nr = text_09 - Trial Nr = 75
#  ---------------
# computing probability for ID 5675 of word Shakespeares
# computing probability for ID 24938 of word Shakespeares
# computing probability for ID 18037 of word Shakespeares
#
# Surprisal score for actual word Shakespeares is 33.7892414231448.
# Text Nr = text_09 - Trial Nr = 76
#  ---------------
# computing probability for ID 37661 of word Stück
#
# Surprisal score for actual word Stück is 16.620380099981784.
# Text Nr = text_09 - Trial Nr = 77
#  ---------------
# computing probability for ID 64 of word \“Hamlet\“.
# computing probability for ID 665 of word \“Hamlet\“.
# computing probability for ID 13934 of word \“Hamlet\“.
# computing probability for ID 10857 of word \“Hamlet\“.
# computing probability for ID 64 of word \“Hamlet\“.
# computing probability for ID 2735 of word \“Hamlet\“.
#
# Surprisal score for actual word \“Hamlet\“. is 74.56849179334984.
# Text Nr = text_09 - Trial Nr = 78
#  ---------------
# computing probability for ID 1550 of word Eine
#
# Surprisal score for actual word Eine is 7.14107451110096.
# Text Nr = text_09 - Trial Nr = 79
#  ---------------
# computing probability for ID 4478 of word Nebenhandlung
# computing probability for ID 7380 of word Nebenhandlung
#
# Surprisal score for actual word Nebenhandlung is 19.628977720100206.
# Text Nr = text_09 - Trial Nr = 80
#  ---------------
# computing probability for ID 2632 of word des
#
# Surprisal score for actual word des is 10.288509936446179.
# Text Nr = text_09 - Trial Nr = 81
#  ---------------
# computing probability for ID 864 of word Stücks
# computing probability for ID 3636 of word Stücks
#
# Surprisal score for actual word Stücks is 31.76019879818144.
# Text Nr = text_09 - Trial Nr = 82
#  ---------------
# computing probability for ID 10152 of word erzählt
# computing probability for ID 1802 of word erzählt
#
# Surprisal score for actual word erzählt is 16.454124694926676.
# Text Nr = text_09 - Trial Nr = 83
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 14.53072225256801.
# Text Nr = text_09 - Trial Nr = 84
#  ---------------
# computing probability for ID 18491 of word Geschichte
#
# Surprisal score for actual word Geschichte is 13.586643711144733.
# Text Nr = text_09 - Trial Nr = 85
#  ---------------
# computing probability for ID 320 of word der
#
# Surprisal score for actual word der is 8.67834235851425.
# Text Nr = text_09 - Trial Nr = 86
#  ---------------
# computing probability for ID 74 of word fiktiven
# computing probability for ID 424 of word fiktiven
# computing probability for ID 15755 of word fiktiven
#
# Surprisal score for actual word fiktiven is 44.27863048290877.
# Text Nr = text_09 - Trial Nr = 87
#  ---------------
# computing probability for ID 49425 of word Edeldame
# computing probability for ID 72 of word Edeldame
# computing probability for ID 1467 of word Edeldame
#
# Surprisal score for actual word Edeldame is 36.511993954236544.
# Text Nr = text_09 - Trial Nr = 88
#  ---------------
# computing probability for ID 51 of word Ophelia,
# computing probability for ID 985 of word Ophelia,
# computing probability for ID 21437 of word Ophelia,
# computing probability for ID 16 of word Ophelia,
#
# Surprisal score for actual word Ophelia, is 39.59411762314534.
# Text Nr = text_09 - Trial Nr = 89
#  ---------------
# computing probability for ID 320 of word der
#
# Surprisal score for actual word der is 9.691344130957154.
# Text Nr = text_09 - Trial Nr = 90
#  ---------------
# computing probability for ID 24732 of word Tochter
#
# Surprisal score for actual word Tochter is 16.836885947146733.
# Text Nr = text_09 - Trial Nr = 91
#  ---------------
# computing probability for ID 32460 of word eines
#
# Surprisal score for actual word eines is 11.183141870116128.
# Text Nr = text_09 - Trial Nr = 92
#  ---------------
# computing probability for ID 47 of word Kämmerers.
# computing probability for ID 13537 of word Kämmerers.
# computing probability for ID 606 of word Kämmerers.
# computing probability for ID 18 of word Kämmerers.
#
# Surprisal score for actual word Kämmerers. is 46.27577028926067.
# Text Nr = text_09 - Trial Nr = 93
#  ---------------
# computing probability for ID 51 of word Ophelia
# computing probability for ID 985 of word Ophelia
# computing probability for ID 21437 of word Ophelia
#
# Surprisal score for actual word Ophelia is 38.78419992559024.
# Text Nr = text_09 - Trial Nr = 94
#  ---------------
# computing probability for ID 91 of word wächst
# computing probability for ID 1712 of word wächst
#
# Surprisal score for actual word wächst is 19.023045332973894.
# Text Nr = text_09 - Trial Nr = 95
#  ---------------
# computing probability for ID 343 of word am
#
# Surprisal score for actual word am is 11.061271444296779.
# Text Nr = text_09 - Trial Nr = 96
#  ---------------
# computing probability for ID 72 of word dänischen
# computing probability for ID 422 of word dänischen
# computing probability for ID 419 of word dänischen
#
# Surprisal score for actual word dänischen is 35.06666039813137.
# Text Nr = text_09 - Trial Nr = 97
#  ---------------
# computing probability for ID 11760 of word Königshof
# computing probability for ID 87 of word Königshof
# computing probability for ID 1469 of word Königshof
#
# Surprisal score for actual word Königshof is 21.330300224327395.
# Text Nr = text_09 - Trial Nr = 98
#  ---------------
# computing probability for ID 587 of word auf,
# computing probability for ID 16 of word auf,
#
# Surprisal score for actual word auf, is 20.71492786496768.
# Text Nr = text_09 - Trial Nr = 99
#  ---------------
# computing probability for ID 3164 of word wo
#
# Surprisal score for actual word wo is 10.991527379061887.
# Text Nr = text_09 - Trial Nr = 100
#  ---------------
# computing probability for ID 2682 of word sie
#
# Surprisal score for actual word sie is 9.47059512163558.
# Text Nr = text_09 - Trial Nr = 101
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 14.847086405715803.
# Text Nr = text_09 - Trial Nr = 102
#  ---------------
# computing probability for ID 10389 of word Geliebte
# computing probability for ID 266 of word Geliebte
# computing probability for ID 3907 of word Geliebte
#
# Surprisal score for actual word Geliebte is 37.209274116012566.
# Text Nr = text_09 - Trial Nr = 103
#  ---------------
# computing probability for ID 2632 of word des
#
# Surprisal score for actual word des is 10.089335029638079.
# Text Nr = text_09 - Trial Nr = 104
#  ---------------
# computing probability for ID 18318 of word Prinzen
# computing probability for ID 590 of word Prinzen
#
# Surprisal score for actual word Prinzen is 25.848152775555285.
# Text Nr = text_09 - Trial Nr = 105
#  ---------------
# computing probability for ID 13934 of word Hamlet
# computing probability for ID 10857 of word Hamlet
#
# Surprisal score for actual word Hamlet is 22.2623548189399.
# Text Nr = text_09 - Trial Nr = 106
#  ---------------
# computing probability for ID 19997 of word wird.
# computing probability for ID 18 of word wird.
#
# Surprisal score for actual word wird. is 22.204446080121727.
# Text Nr = text_09 - Trial Nr = 107
#  ---------------
# computing probability for ID 5330 of word Ihre
#
# Surprisal score for actual word Ihre is 9.97217103508223.
# Text Nr = text_09 - Trial Nr = 108
#  ---------------
# computing probability for ID 6732 of word Beziehung
# computing probability for ID 48704 of word Beziehung
#
# Surprisal score for actual word Beziehung is 16.5788059545276.
# Text Nr = text_09 - Trial Nr = 109
#  ---------------
# computing probability for ID 19997 of word wird
#
# Surprisal score for actual word wird is 15.094985458883682.
# Text Nr = text_09 - Trial Nr = 110
#  ---------------
# computing probability for ID 1420 of word von
#
# Surprisal score for actual word von is 13.997209670968488.
# Text Nr = text_09 - Trial Nr = 111
#  ---------------
# computing probability for ID 21180 of word ihrem
# computing probability for ID 305 of word ihrem
#
# Surprisal score for actual word ihrem is 18.739013329848074.
# Text Nr = text_09 - Trial Nr = 112
#  ---------------
# computing probability for ID 19472 of word Vater
#
# Surprisal score for actual word Vater is 15.491179820964275.
# Text Nr = text_09 - Trial Nr = 113
#  ---------------
# computing probability for ID 283 of word und
#
# Surprisal score for actual word und is 17.664714229044428.
# Text Nr = text_09 - Trial Nr = 114
#  ---------------
# computing probability for ID 21180 of word ihrem
# computing probability for ID 305 of word ihrem
#
# Surprisal score for actual word ihrem is 18.02514645554047.
# Text Nr = text_09 - Trial Nr = 115
#  ---------------
# computing probability for ID 36842 of word Bruder
#
# Surprisal score for actual word Bruder is 16.39022730490522.
# Text Nr = text_09 - Trial Nr = 116
#  ---------------
# computing probability for ID 78 of word jedoch
# computing probability for ID 12072 of word jedoch
#
# Surprisal score for actual word jedoch is 20.78712783070785.
# Text Nr = text_09 - Trial Nr = 117
#  ---------------
# computing probability for ID 22244 of word missbilligt.
# computing probability for ID 70 of word missbilligt.
# computing probability for ID 20282 of word missbilligt.
# computing probability for ID 18 of word missbilligt.
#
# Surprisal score for actual word missbilligt. is 40.80297831302364.
# Text Nr = text_09 - Trial Nr = 118
#  ---------------
# computing probability for ID 722 of word Sie
#
# Surprisal score for actual word Sie is 9.0337453774836.
# Text Nr = text_09 - Trial Nr = 119
#  ---------------
# computing probability for ID 518 of word bezweifeln,
# computing probability for ID 4923 of word bezweifeln,
# computing probability for ID 23013 of word bezweifeln,
# computing probability for ID 16 of word bezweifeln,
#
# Surprisal score for actual word bezweifeln, is 35.233562122336075.
# Text Nr = text_09 - Trial Nr = 120
#  ---------------
# computing probability for ID 5582 of word dass
#
# Surprisal score for actual word dass is 7.142636287818241.
# Text Nr = text_09 - Trial Nr = 121
#  ---------------
# computing probability for ID 13934 of word Hamlet
# computing probability for ID 10857 of word Hamlet
#
# Surprisal score for actual word Hamlet is 26.747250364787856.
# Text Nr = text_09 - Trial Nr = 122
#  ---------------
# computing probability for ID 2327 of word die
#
# Surprisal score for actual word die is 12.021459102632027.
# Text Nr = text_09 - Trial Nr = 123
#  ---------------
# computing probability for ID 438 of word ehrliche
# computing probability for ID 618 of word ehrliche
#
# Surprisal score for actual word ehrliche is 25.814788190837113.
# Text Nr = text_09 - Trial Nr = 124
#  ---------------
# computing probability for ID 1947 of word Absicht
# computing probability for ID 1450 of word Absicht
#
# Surprisal score for actual word Absicht is 28.47119096943696.
# Text Nr = text_09 - Trial Nr = 125
#  ---------------
# computing probability for ID 8491 of word hat,
# computing probability for ID 16 of word hat,
