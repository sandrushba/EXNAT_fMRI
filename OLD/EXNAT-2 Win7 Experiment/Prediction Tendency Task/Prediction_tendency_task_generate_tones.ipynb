# %% [markdown]
# #Prediction Tendency Task
#
# I based my code on this preprint by Juliane Schubert et al. (2022):
# https://www.biorxiv.org/content/10.1101/2022.04.22.489224v1.full.pdf
#
# Additionally, Juliane was so kind as to give me access to a repo containing a lot scripts for the implementation of the paradigm in MATLAB.

# %%
""" SETTINGS """

# import modules
import numpy as np
import pandas as pd
import random
import time
import matplotlib.pyplot as plt # for testing

# for hidden markov models:
# !pip install hmmlearn
from hmmlearn import hmm

# ------------------------------------

# Settings for the prediction tendency task:

# for the sounds:
tones = [440, 587, 782, 1043]  # Pure tone frequencies in Hz
#tone_duration = 0.1  # Duration of each pure tone in seconds (each lasted 100 ms)
#tone_rate = 3  # Rate of pure tone presentation in Hz
#tone_volume = 1 # use full volume, but you can adjust this later if you determined a hearing threshold
#audio_sample_freq = 44100 # 44100 Hz --> audio sampling rate at the lab (according to Frauke)
#tones_iti = 1/3
#tone_fade = 5e-3

# for the paradigm:
block_trials = 1505  # Number of trials per entropy condition
#trigger_ordered = 1
#trigger_random = 2

# %%
# Function for testing if the generation functions actually work as
# intended and produce the correct matrices:

''' Function for calculating transition probabilities of 1 sequence'''
def calculate_transition_probabilities(sequence):
    transition_counts = np.zeros((len(tones), len(tones)))

    for i in range(1, len(sequence)):
        prev_tone = sequence[i-1]
        current_tone = sequence[i]
        prev_tone_index = tones.index(prev_tone)
        current_tone_index = tones.index(current_tone)

        transition_counts[prev_tone_index][current_tone_index] += 1

    # Replace zero counts with a small value
    transition_counts[transition_counts == 0] = 1e-6

    transition_probs = transition_counts / np.sum(transition_counts, axis=1, keepdims=True)
    #print(transition_counts)
    return transition_probs

# %%
''' Generate Tone Sequence for the Ordered Condition '''

def generate_ordered_seq(tones, len_sequence):

  # collect tones here:
  final_sequence = []

  # check how many transitions we need for each cell:
  # careful, not tones, but transitions, so subtract 1 from sequence length
  n_transitions_25 = int(( (len_sequence - 1) / 4) / 100 * 25)
  n_transitions_75 = int(( (len_sequence - 1) / 4) / 100 * 75)

  print("25%:", n_transitions_25, "75%:", n_transitions_75)

  # Now generate small transition snippets: We can either go up (e.g. 1 - 2 or 0 - 1)
  # or we can repeat the same tone again (e.g. 3 - 3).
  # For each tone, we need 75% of "up" transitions and 25% of "rep" transitions:
  up_0 = [[0,1]] * n_transitions_75
  rep_0 = [[0,0]] * n_transitions_25
  # combine & shuffle them so we have all transitions that start with 0 in one list:
  all_0 = up_0 + rep_0
  random.shuffle(all_0)
  #print(all_0)

  # Do the same for the other tones' transition lists:
  up_1 = [[1,2]] * n_transitions_75
  rep_1 = [[1,1]] * n_transitions_25
  all_1 = up_1 + rep_1
  random.shuffle(all_1)

  up_2 = [[2,3]] * n_transitions_75
  rep_2 = [[2,2]] * n_transitions_25
  all_2 = up_2 + rep_2
  random.shuffle(all_2)

  up_3 = [[3,0]] * n_transitions_75
  rep_3 = [[3,3]] * n_transitions_25
  all_3 = up_3 + rep_3
  random.shuffle(all_3)

  # put them into a dictionary for easier handling:
  transition_lists = {0: all_0,
                      1: all_1,
                      2: all_2,
                      3: all_3}

  # Idea:
  # I will start with a random tone and pick one transition from the corresponding list (e.g. if I pick 1 I need to take a small transition from all_1)
  # That's our first small transition that we'll put into the final sequence.
  # Then I will remove transition I picked from the list (e.g. remove one [1,2] list from all_1).

  # Next I will take the last element from the transition I picked and randomly draw a transition from the corresponding list.
  # E.g. if my last transition was [1,2], I need to pick a transition from all_2
  curr_idx = random.choice(range(len(tones)))
  print("starting with tone at idx", curr_idx)

  # Now create a loop that only ends if we reach a dead end (e.g. if remaining transitions
  # don't match curr_idx anymore, I think such a scenario might be possible)
  # or if all our lists are empty.

  while True:

    # if there are still transitions left for us to pick:
    if len(transition_lists[curr_idx]) > 0:

      # choose a transition for the current tone:
      curr_trans = random.choice(transition_lists[curr_idx])

      # put the transition into the final sequence:
      final_sequence.extend([curr_trans])

      # remove 1 matching transition from the list we got curr_trans from:
      transition_lists[curr_idx].remove(curr_trans)

      # get last element from the transition so we can pick the next transition:
      curr_idx = curr_trans[1]

    else:
      # If we reached a dead end and there are still transitions to pick:
      if any(len(transition_list) > 0 for transition_list in transition_lists.values()):

        print("Reached a dead end! Using backtracking now!")
        # Remove the last 20 transitions from the final sequence
        for _ in range(200):

          # get last transition list from final_sequence
          last_trans = final_sequence.pop(len(final_sequence)-1)
          prev_idx = last_trans[0]

          # Add the removed transition back to the list so it can be picked again
          transition_lists[prev_idx].append(last_trans)
          #print("removed transition")

        # Start over with new transition (depending on last transition in final_sequence)
        curr_idx = final_sequence[-1][1]

      else:
        # All transitions have been used, exit the loop
        break

  #print(len(final_sequence))
  #print(final_sequence)

  # Now as you can see, we need to shorten the sequence a bit because we still only have the transitions, not single tones.
  # So we want to go from this: [1,1], [1,2], [2,3], [3,0] to this: [1, 1, 2, 3, 0]
  # As you can see we need to keep the values from the first transition and only the second value from all others.
  sequence = final_sequence[0]
  # remove first transition from final_sequence:
  final_sequence.pop(0)
  # loop the rest of the transitions and always append the second value from each transition to the sequence:
  for transition in final_sequence:
    sequence.append(transition[1])

  # Now turn 0, 1, 2 and 3 into corresponding frequencies in list tones:
  sequence = [tones[idx] for idx in sequence]

  return(sequence)


# Test case:

tones = [440, 587, 782, 1043]  # Pure tone frequencies in Hz
len_sequence = 1505 # careful, I need a non-float number of transitions for the 75% and 25% cells, so I need 1505 values

sequence = generate_ordered_seq(tones, len_sequence)

print("------------------")

# Check our transition probability matrix
print(calculate_transition_probabilities(sequence))

print("------------------")

# Check how many occurances we have for each tone:
print("count of freq. 440 Hz in sequence:", sequence.count(440))
print("count of freq. 587 Hz in sequence:", sequence.count(587))
print("count of freq. 782 Hz in sequence:", sequence.count(782))
print("count of freq. 1043 Hz in sequence:", sequence.count(1043))

print("------------------")

# Check length of sequence:
print("length of generated sequence:", len(sequence))
# Okay so we have 1 occurance too much for one tone, but that's okay I guess.
# We'll probably have to exclude some trials in the analysis anyway.

print("sequence:", sequence)
# Out:
# 25%: 94 75%: 282
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# ------------------
# [[0.25 0.75 0.   0.  ]
#  [0.   0.25 0.75 0.  ]
#  [0.   0.   0.25 0.75]
#  [0.75 0.   0.   0.25]]
# ------------------
# count of freq. 440 Hz in sequence: 376
# count of freq. 587 Hz in sequence: 376
# count of freq. 782 Hz in sequence: 377
# count of freq. 1043 Hz in sequence: 376
# ------------------
# length of generated sequence: 1505
# sequence: [782, 1043, 440, 587, 782, 1043, 440, 587, 782, 782, 1043, 440, 587, 782, 782, 782, 1043, 440, 587, 782, 1043, 440, 587, 587, 587, 782, 782, 782, 1043, 440, 587, 587, 782, 1043, 440, 587, 782, 1043, 440, 440, 587, 587, 782, 1043, 440, 440, 587, 782, 782, 1043, 440, 440, 587, 587, 587, 782, 1043, 440, 440, 587, 782, 1043, 440, 440, 440, 587, 782, 782, 782, 1043, 440, 587, 782, 782, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 440, 440, 587, 587, 782, 1043, 440, 440, 587, 782, 1043, 440, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 440, 440, 440, 440, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 1043, 1043, 440, 440, 587, 782, 782, 1043, 440, 587, 587, 782, 782, 782, 1043, 440, 587, 587, 782, 1043, 440, 440, 587, 782, 782, 1043, 440, 587, 782, 1043, 440, 587, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 587, 782, 1043, 440, 440, 587, 782, 1043, 440, 440, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 440, 587, 782, 1043, 1043, 440, 587, 782, 782, 1043, 440, 587, 782, 782, 1043, 440, 440, 587, 587, 587, 782, 1043, 1043, 1043, 440, 587, 587, 782, 1043, 440, 587, 782, 1043, 1043, 440, 440, 440, 440, 587, 782, 1043, 1043, 440, 587, 782, 1043, 1043, 440, 587, 782, 1043, 440, 440, 587, 782, 782, 1043, 440, 440, 587, 782, 1043, 440, 440, 587, 587, 587, 782, 1043, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 440, 587, 782, 782, 1043, 1043, 440, 440, 440, 587, 782, 782, 1043, 440, 587, 782, 1043, 1043, 440, 587, 587, 587, 782, 1043, 440, 440, 587, 587, 782, 1043, 1043, 1043, 440, 587, 782, 782, 1043, 440, 587, 782, 1043, 440, 440, 587, 782, 1043, 1043, 440, 440, 440, 587, 782, 782, 782, 782, 1043, 440, 587, 782, 782, 1043, 440, 440, 587, 782, 1043, 440, 587, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 440, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 440, 440, 440, 587, 782, 1043, 1043, 440, 587, 782, 1043, 1043, 1043, 440, 587, 587, 782, 782, 782, 1043, 1043, 440, 587, 782, 782, 1043, 440, 587, 782, 782, 1043, 1043, 440, 587, 782, 1043, 440, 587, 587, 782, 1043, 1043, 440, 440, 587, 782, 782, 782, 1043, 440, 587, 782, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 782, 1043, 440, 587, 587, 587, 782, 1043, 1043, 440, 587, 782, 1043, 440, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 440, 440, 587, 782, 1043, 440, 587, 587, 782, 1043, 440, 440, 440, 440, 587, 782, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 440, 587, 782, 1043, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 782, 1043, 440, 440, 587, 587, 587, 782, 1043, 440, 587, 587, 587, 782, 1043, 440, 587, 587, 587, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 440, 587, 782, 1043, 440, 587, 587, 587, 782, 782, 1043, 440, 587, 782, 1043, 1043, 1043, 440, 440, 587, 782, 1043, 440, 587, 782, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 1043, 1043, 440, 440, 587, 782, 1043, 440, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 440, 587, 587, 782, 1043, 1043, 440, 587, 782, 1043, 440, 587, 587, 782, 1043, 1043, 1043, 440, 587, 587, 782, 1043, 440, 587, 782, 1043, 440, 440, 587, 587, 782, 1043, 440, 440, 440, 440, 587, 587, 782, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 782, 782, 1043, 440, 440, 587, 587, 782, 1043, 1043, 440, 587, 782, 1043, 1043, 1043, 1043, 440, 587, 782, 782, 782, 1043, 440, 440, 587, 782, 1043, 440, 587, 587, 782, 1043, 440, 587, 782, 782, 1043, 440, 587, 782, 1043, 440, 587, 782, 1043, 440, 440, 587, 782, 1043, 440, 587, 782, 1043, 1043, 440, 587, 782, 782, 782, 1043, 1043, 440, 587, 782, 782, 782, 1043, 440, 440, 587,  ...

# %%
''' Generate Tone Sequence for the Ordered Condition '''

def generate_random_seq(tones, len_sequence):

  # collect tones here:
  final_sequence = []

  # check how many transitions we need for each cell:
  # careful, not tones, but transitions, so subtract 1 from sequence length
  n_transitions_25 = int(( (len_sequence - 1) / 4) / 100 * 25)

  print("25%:", n_transitions_25)

  # Now generate small transition snippets: We can either go up (e.g. 1 - 2 or 0 - 1)
  # or we can repeat the same tone again (e.g. 3 - 3).
  # For each tone, we need 75% of "up" transitions and 25% of "rep" transitions:
  trans0_0 = [[0,0]] * n_transitions_25
  trans1_0 = [[0,1]] * n_transitions_25
  trans2_0 = [[0,2]] * n_transitions_25
  trans3_0 = [[0,3]] * n_transitions_25
  # combine & shuffle them so we have all transitions that start with 0 in one list:
  all_0 = trans0_0 + trans1_0 + trans2_0 + trans3_0
  random.shuffle(all_0)
  #print(all_0)

  # Do the same for the other tones' transition lists:
  trans0_1 = [[1,0]] * n_transitions_25
  trans1_1 = [[1,1]] * n_transitions_25
  trans2_1 = [[1,2]] * n_transitions_25
  trans3_1 = [[1,3]] * n_transitions_25
  all_1 = trans0_1 + trans1_1 + trans2_1 + trans3_1
  random.shuffle(all_1)

  trans0_2 = [[2,0]] * n_transitions_25
  trans1_2 = [[2,1]] * n_transitions_25
  trans2_2 = [[2,2]] * n_transitions_25
  trans3_2 = [[2,3]] * n_transitions_25
  all_2 = trans0_2 + trans1_2 + trans2_2 + trans3_2
  random.shuffle(all_2)

  trans0_3 = [[3,0]] * n_transitions_25
  trans1_3 = [[3,1]] * n_transitions_25
  trans2_3 = [[3,2]] * n_transitions_25
  trans3_3 = [[3,3]] * n_transitions_25
  all_3 = trans0_3 + trans1_3 + trans2_3 + trans3_3
  random.shuffle(all_3)

  # put them into a dictionary for easier handling:
  transition_lists = {0: all_0,
                      1: all_1,
                      2: all_2,
                      3: all_3}

  # Idea:
  # I will start with a random tone and pick one transition from the corresponding list (e.g. if I pick 1 I need to take a small transition from all_1)
  # That's our first small transition that we'll put into the final sequence.
  # Then I will remove transition I picked from the list (e.g. remove one [1,2] list from all_1).

  # Next I will take the last element from the transition I picked and randomly draw a transition from the corresponding list.
  # E.g. if my last transition was [1,2], I need to pick a transition from all_2
  curr_idx = random.choice(range(len(tones)))
  print("starting with tone at idx", curr_idx)

  # Now create a loop that only ends if we reach a dead end (e.g. if remaining transitions
  # don't match curr_idx anymore, I think such a scenario might be possible)
  # or if all our lists are empty.

  while True:

    # if there are still transitions left for us to pick:
    if len(transition_lists[curr_idx]) > 0:

      # choose a transition for the current tone:
      curr_trans = random.choice(transition_lists[curr_idx])

      # put the transition into the final sequence:
      final_sequence.extend([curr_trans])

      # remove 1 matching transition from the list we got curr_trans from:
      transition_lists[curr_idx].remove(curr_trans)

      # get last element from the transition so we can pick the next transition:
      curr_idx = curr_trans[1]

    else:
      # If we reached a dead end and there are still transitions to pick:
      if any(len(transition_list) > 0 for transition_list in transition_lists.values()):

        print("Reached a dead end! Using backtracking now!")
        # Remove the last 20 transitions from the final sequence
        for _ in range(200):

          # get last transition list from final_sequence
          last_trans = final_sequence.pop(len(final_sequence)-1)
          prev_idx = last_trans[0]

          # Add the removed transition back to the list so it can be picked again
          transition_lists[prev_idx].append(last_trans)
          #print("removed transition")

        # Start over with new transition (depending on last transition in final_sequence)
        curr_idx = final_sequence[-1][1]

      else:
        # All transitions have been used, exit the loop
        break

  #print(len(final_sequence))
  #print(final_sequence)

  # Now as you can see, we need to shorten the sequence a bit because we still only have the transitions, not single tones.
  # So we want to go from this: [1,1], [1,2], [2,3], [3,0] to this: [1, 1, 2, 3, 0]
  # As you can see we need to keep the values from the first transition and only the second value from all others.
  sequence = final_sequence[0]
  # remove first transition from final_sequence:
  final_sequence.pop(0)
  # loop the rest of the transitions and always append the second value from each transition to the sequence:
  for transition in final_sequence:
    sequence.append(transition[1])

  # Now turn 0, 1, 2 and 3 into corresponding frequencies in list tones:
  sequence = [tones[idx] for idx in sequence]

  return(sequence)


# Test case:

tones = [440, 587, 782, 1043]  # Pure tone frequencies in Hz
len_sequence = 1505 # careful, I need a non-float number of transitions for the 75% and 25% cells, so I need 1505 values

sequence = generate_random_seq(tones, len_sequence)

print("------------------")

# Check our transition probability matrix
print(calculate_transition_probabilities(sequence))

print("------------------")

# Check how many occurances we have for each tone:
print("count of freq. 440 Hz in sequence:", sequence.count(440))
print("count of freq. 587 Hz in sequence:", sequence.count(587))
print("count of freq. 782 Hz in sequence:", sequence.count(782))
print("count of freq. 1043 Hz in sequence:", sequence.count(1043))

print("------------------")

# Check length of sequence:
print("length of generated sequence:", len(sequence))
# Okay so we have 1 occurance too much for one tone, but that's okay I guess.
# We'll probably have to exclude some trials in the analysis anyway.

print("sequence:", sequence)

# %%
# prepare 1000 sound sequences for both conditions
 # (so that basically I could run this study until I'm 80
 # and won't run out of sequences)
import pandas as pd


tones = [440, 587, 782, 1043]  # Pure tone frequencies in Hz
len_sequence = 1505 # careful, I need a non-float number of transitions for the 75% and 25% cells, so I need 1505 values

# Create empty data frames for both conditions:
df_ordered_seqs = pd.DataFrame()
df_random_seqs = pd.DataFrame()

# do this 1000x
for i in range(1000):
  print(i)
  # Generate the trial sequences for both entropy conditions
  ordered_sequence = generate_ordered_seq(tones, len_sequence)
  random_sequence = generate_random_seq(tones, len_sequence)

  # append current arrays as new rows to the 2 data frames
  df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
  df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# Out:
# 0
# 25%: 94 75%: 282
# starting with tone at idx 3
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 1
# 25%: 94 75%: 282
# starting with tone at idx 1
# 25%: 94
# starting with tone at idx 1
# 2
# 25%: 94 75%: 282
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 3
# 25%: 94 75%: 282
# starting with tone at idx 2
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 4
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 5
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 6
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 7
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 8
# 25%: 94 75%: 282
# starting with tone at idx 0
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# 9
# 25%: 94 75%: 282
# starting with tone at idx 0
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 10
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 11
# 25%: 94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 12
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# 13
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 14
# 25%: 94 75%: 282
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 15
# 25%: 94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 1
# 16
# 25%: 94 75%: 282
# starting with tone at idx 1
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 17
# 25%: 94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 18
# 25%: 94 75%: 282
# starting with tone at idx 0
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 19
# 25%: 94 75%: 282
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 20
# 25%: 94 75%: 282
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 21
# 25%: 94 75%: 282
# starting with tone at idx 3
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 22
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# 23
# 25%: 94 75%: 282
# starting with tone at idx 3
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 24
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# 25
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# 26
# 25%: 94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 27
# 25%: 94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 1
# 28
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# 29
# 25%: 94 75%: 282
# starting with tone at idx 1
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 30
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 31
# 25%: 94 75%: 282
# starting with tone at idx 1
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 32
# 25%: 94 75%: 282
# starting with tone at idx 0
# 25%: 94
# starting with tone at idx 0
# 33
# 25%: 94 75%: 282
# starting with tone at idx 0
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 34
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 35
# 25%: 94 75%: 282
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 36
# 25%: 94 75%: 282
# starting with tone at idx 1
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 37
# 25%: 94 75%: 282
# starting with tone at idx 2
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# 38
# 25%: 94 75%: 282
# starting with tone at idx 2
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 39
# 25%: 94 75%: 282
# starting with tone at idx 0
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 40
# 25%: 94 75%: 282
# starting with tone at idx 1
# 25%: 94
# starting with tone at idx 3
# 41
# 25%: 94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# 42
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# 43
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# 44
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 45
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# 46
# 25%: 94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 47
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 48
# 25%: 94 75%: 282
# starting with tone at idx 3
# 25%: 94
# starting with tone at idx 2
# 49
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# 50
# 25%: 94 75%: 282
# starting with tone at idx 0
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# 51
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 52
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# 53
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 3
# 54
# 25%: 94 75%: 282
# starting with tone at idx 0
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 55
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# 56
# 25%: 94 75%: 282
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 57
# 25%: 94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 58
# 25%: 94 75%: 282
# starting with tone at idx 0
# 25%: 94
# starting with tone at idx 2
# 59
# 25%: 94 75%: 282
# starting with tone at idx 3
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 60
# 25%: 94 75%: 282
# starting with tone at idx 2
# 25%: 94
# starting with tone at idx 0
# 61
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 62
# 25%: 94 75%: 282
# starting with tone at idx 3
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# 981
# 25%: 94 75%: 282
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 982
# 25%: 94 75%: 282
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 983
# 25%: 94 75%: 282
# starting with tone at idx 2
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 984
# 25%: 94 75%: 282
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 985
# 25%: 94 75%: 282
# starting with tone at idx 0
# 25%: 94
# starting with tone at idx 0
# 986
# 25%: 94 75%: 282
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# 987
# 25%: 94 75%: 282
# starting with tone at idx 3
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 988
# 25%:
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
#  94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# 989
# 25%: 94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 990
# 25%: 94 75%: 282
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# 991
# 25%: 94 75%: 282
# starting with tone at idx 0
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 992
# 25%: 94 75%: 282
# starting with tone at idx 1
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 993
# 25%: 94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 994
# 25%: 94 75%: 282
# starting with tone at idx 3
# 25%: 94
# starting with tone at idx 3
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# 995
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# 996
# 25%: 94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 3
# 997
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# Reached a dead end! Using backtracking now!
# 998
# 25%: 94 75%: 282
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 2
# 999
# 25%: 94 75%: 282
# starting with tone at idx 1
# Reached a dead end! Using backtracking now!
# 25%: 94
# starting with tone at idx 0
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# Reached a dead end! Using backtracking now!
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ordered_seqs = df_ordered_seqs.append(pd.Series(ordered_sequence), ignore_index = True)
# <ipython-input-122-f653ad1abf66>:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random_seqs = df_random_seqs.append(pd.Series(random_sequence), ignore_index = True)

# %%
# download dataframes
from google.colab import files

df_ordered_seqs.to_csv('df_ordered_seqs.csv', encoding = "utf-8-sig")
df_random_seqs.to_csv('df_random_seqs.csv', encoding = "utf-8-sig")
files.download('df_ordered_seqs.csv')
files.download('df_random_seqs.csv')

# %% [markdown]
# ------------------------------------------------
#
# OLD SNIPPETS:

# %%
# Works but works with probabilities (so it's not exact) and not with fixed frequencies

def generate_trial_sequence(entropy_level):

    # check how many tones we have - this determines
    # how big our matrices with the transition probabilities
    # need to be:
    n_features = len(tones)

    # create emission matrix: We want to emit
    # the given state with 100% probability
    # (feels a bit odd to explicitly specify that,
    # but we need it for the HMM function later)
    emission_matrix = np.eye(n_features)
    #print(emission_matrix)


    if entropy_level == "ordered":
        # create a matrix with transition probabilities
        # for the ordered condition:
        transition_matrix = [[0.25, 0.75, 0., 0.],
                             [0., 0.25, 0.75, 0.],
                             [0., 0., 0.25, 0.75],
                             [0.75, 0., 0., 0.25]]
        #print("ordered transition probabilities matrix:", transition_matrix)

    elif entropy_level == "random":
        # create a matrix with transition probabilities
        # for the random condition:
        transition_matrix = [[0.25, 0.25, 0.25, 0.25],
                             [0.25, 0.25, 0.25, 0.25],
                             [0.25, 0.25, 0.25, 0.25],
                             [0.25, 0.25, 0.25, 0.25]]
        #print("random transition probabilities matrix:", transition_matrix)




    # Create an HMM model
    model = hmm.MultinomialHMM(n_components = n_features,
                               n_trials = 1,
                               verbose = False)

    model.startprob_ = np.ones(n_features) / n_features  # Set equal initial probabilities
    model.transmat_ = transition_matrix
    model.emissionprob_ = emission_matrix

    # Generate a sequence of pure tones
    sequence, _ = model.sample(n_samples = 1500, random_state = None)

    pure_tones_sequence = []

    for sublist in sequence:
      #print(sublist)
      index = np.where(sublist != 0)[0][0]  # Get the index of the non-zero element
      #print(index)
      pure_tone = tones[index]  # Retrieve the corresponding pure tone
      pure_tones_sequence.append(pure_tone)

    # TO DO:
    # The transition probabilities don't match exactly the probabilities I specified in my transition matrix.
    # Idea: Polish it a bit manually, so I get exactly 0%, 25% and 75% transition probabilities in the
    # output? Or is this not a problem?

    return(pure_tones_sequence)

# Generate the trial sequences for both entropy conditions
ordered_sequence = generate_trial_sequence("ordered")
random_sequence = generate_trial_sequence("random")
print(ordered_sequence)

calculate_transition_probabilities(ordered_sequence)

# %%
# also works, but this is for the snippet above:

'''
Generate 10,000 sequences for each condition and
test their transition probabilities
'''
# Create empty data frames for both conditions:
df_ordered_test = pd.DataFrame()
df_random_test = pd.DataFrame()

# do this 10,000x
for i in range(10000):
  print(i)
  # Generate the trial sequences for both entropy conditions
  ordered_sequence = generate_trial_sequence("ordered")
  random_sequence = generate_trial_sequence("random")

  # append current arrays as new rows to the 2 data frames
  df_ordered_test = df_ordered_test.append(pd.Series(ordered_sequence), ignore_index = True)
  df_random_test = df_random_test.append(pd.Series(random_sequence), ignore_index = True)


# tones was defined above like this:
#tones = [440, 587, 782, 1043]

# create 2 empty average transition probability
# matrices for our 2 conditions:
avg_transition_probs_ordered = np.zeros((len(tones), len(tones)))
avg_transition_probs_random = np.zeros((len(tones), len(tones)))

# loop rows in df_ordered_test:
for _, row in df_ordered_test.iterrows():
    # get current row
    sequence = row.values
    # calculate transition probabilities
    transition_probs = calculate_transition_probabilities(sequence)
    # add matrix values to our matrix with the average values
    avg_transition_probs_ordered += transition_probs

# do the same for the dataframe df_random_test:
for _, row in df_random_test.iterrows():
    sequence = row.values
    transition_probs = calculate_transition_probabilities(sequence)
    avg_transition_probs_random += transition_probs

# Divide values in the matrices by the total number of rows in
# each dataframe to get average transition probabilities
avg_transition_probs_ordered /= len(df_ordered_test)
avg_transition_probs_random /= len(df_random_test)



# Set numpy print options
np.set_printoptions(precision = 3, suppress = True)

# Display the transition probability matrices
print("Average Ordered Transition Probabilities Matrix:")
print(avg_transition_probs_ordered)
print()

# Display the transition probability matrices
print("Average Ordered Transition Probabilities Matrix:")
print(avg_transition_probs_random)
print()

# %%
#This gets stuck and doesn't produce the correct matrices:


import random
import numpy as np
# turn off scientific notation:
np.set_printoptions(precision = 6, suppress = True)


# Okay so the logic behind this is that I want a sequence with 4 tones (all occuring equally often) and
# certain transition probabilities of 0, 25 or 75%. So I use 2 kinds of counters, one for the
# number of occurances of each tone and one kind for the transitions.
# I'm basically creating a more controlled HMM sequence with fixed numbers of tones & transitions.


def generate_sequence_from_matrix(condition, stimuli, len_sequence):

    # how many stimuli do we have?
    num_stimuli = len(stimuli)

    # specify transition probability matrices depending on condition:
    if condition == "ordered":

        # start with empty sequence:
        sequence = []

        # check how many transitions we can use for the 25% and 75% cells of the matrices.
        # This basically tells us how often we can choose A or B for example if the current value is A.
        count25_0 = (len_sequence / 4) / 100 * 25
        count75_0 = (len_sequence / 4) / 100 * 75
        count25_1 = (len_sequence / 4) / 100 * 25
        count75_1 = (len_sequence / 4) / 100 * 75
        count25_2 = (len_sequence / 4) / 100 * 25
        count75_2 = (len_sequence / 4) / 100 * 75
        count25_3 = (len_sequence / 4) / 100 * 25
        count75_3 = (len_sequence / 4) / 100 * 75

        # count instances of each stimulus so we make sure there
        # are exactly equal amounts of them in the sequence:
        count_0 = 0
        count_1 = 0
        count_2 = 0
        count_3 = 0

        # as a starting point, choose random stimulus from list of tones:
        current_stimulus = random.choice(stimuli)
        # append current stimulus to the sequence
        sequence.append(current_stimulus)

        # now loop length of sequence you want to generate
        for x in range(len_sequence-1):

            # get idx of current stimulus in the stimulus list
            current_stimulus_index = stimuli.index(current_stimulus)
            #print(current_stimulus_index)

            # STIMULUS 0:
            # If the current stimulus is 0 and we still have enough stimuli left of
            # stimuli 0 and 1, you can choose. If not, take what's left.
            if current_stimulus_index == 0:
              if count_0 < (len_sequence / num_stimuli) and count_1 < (len_sequence / num_stimuli) and count75_0 > 0 and count25_0 > 0:
                # randomly choose next stimulus based on our pre-defined probabilities:
                next_stimulus_index = random.choices([0,1], [.25, .75])[0]
                if next_stimulus_index == 1:
                  count75_0 = count75_0 - 1 # one less transition from 0 to 1 left - update counter!
                else:
                  count25_0 = count25_0 - 1 # one less transition from 0 to 0 left - update counter!
              else:
                # if we can't use stimulus 0 anymore and the transition to 1 is still allowed:
                if count_0 >= (len_sequence / num_stimuli) and count25_0 > 0:
                  #print("counter 0 reached the limit!")
                  next_stimulus_index = 1
                  count75_0 = count75_0 - 1
                # if we can't use stimulus 1 anymore and the transition to 0 is still allowed:
                elif count_1 >= (len_sequence / num_stimuli) and count75_0 > 0:
                  #print("counter 1 reached the limit!")
                  next_stimulus_index = 0
                  count25_0 = count25_0 - 1
                else:
                  print("0: something odd is happening here:", "count 1: ", count_1, "count 0: ", count_0, count75_0, count25_0)
                  # couldn't find solution - recursion!
                  generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
            # STIMULUS 1:
            # If the current stimulus is 1 and we still have enough stimuli left of
            # stimuli 1 and 2, you can choose. If not, take what's left.
            if current_stimulus_index == 1:
              if count_1 < (len_sequence / num_stimuli) and count_2 < (len_sequence / num_stimuli) and count75_1 > 0 and count25_1 > 0:
                # randomly choose next stimulus based on our pre-defined probabilities:
                next_stimulus_index = random.choices([1,2], [.25, .75])[0]
                if next_stimulus_index == 2:
                  count75_1 = count75_1 - 1 # one less transition from 1 to 2 left - update counter!
                else:
                  count25_1 = count25_1 - 1 # one less transition from 1 to 1 left - update counter!
              else:
                # if we can't use stimulus 1 anymore and the transition to 2 is still allowed:
                if count_1 >= (len_sequence / num_stimuli) and count25_1 > 0:
                  next_stimulus_index = 2
                  count75_1 = count75_1 - 1
                  #print("counter 1 reached the limit!")
                # if we can't use stimulus 2 anymore and the transition to 1 is still allowed:
                elif count_2 >= (len_sequence / num_stimuli) and count75_1 > 0:
                  #print("counter 2 reached the limit!")
                  count25_1 = count25_1 - 1
                  next_stimulus_index = 1
                else:
                  print("1: something odd is happening here:", "count 2: ", count_2, "count 1: ", count_1, count75_1, count25_1)
                  # couldn't find solution - recursion!
                  generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
            # STIMULUS 2:
            # If the current stimulus is 2 and we still have enough stimuli left of
            # stimuli 2 and 3, you can choose. If not, take what's left.
            if current_stimulus_index == 2:
              if count_2 < (len_sequence / num_stimuli) and count_3 < (len_sequence / num_stimuli) and count75_2 > 0 and count25_2 > 0 :
                # randomly choose next stimulus based on our pre-defined probabilities:
                next_stimulus_index = random.choices([2,3], [.25, .75])[0]
                if next_stimulus_index == 3:
                  count75_2 = count75_2 - 1 # one less transition from 2 to 3 left - update counter!
                else:
                  count25_2 = count25_2 - 1 # one less transition from 2 to 2 left - update counter!
              # if at least one of the options can't be used anymore:
              else:
                # if we can't use stimulus 2 anymore and the transition to 3 is still allowed:
                if count_2 >= (len_sequence / num_stimuli) and count75_2 > 0:
                  #print("counter 2 reached the limit!")
                  count75_2 = count75_2 - 1  # one less transition from 2 to 3 left - update counter!
                  next_stimulus_index = 3
                # if we can't use stimulus 3 anymore and the transition to 2 is still allowed:
                elif count_3 >= (len_sequence / num_stimuli) and count25_2 > 0:
                  #print("counter 3 reached the limit!")
                  count25_2 = count25_2 - 1  # one less transition from 2 to 2 left - update counter!
                  next_stimulus_index = 2
                else:
                  print("2: something odd is happening here:", "count 3: ", count_3, "count 2: ", count_2, count75_2, count25_2)
                  # couldn't find solution - recursion!
                  generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
            # STIMULUS 3:
            # If the current stimulus is 3 and we still have enough stimuli left of
            # stimuli 3 and 0, you can choose. If not, take what's left.
            if current_stimulus_index == 3:
              if count_3 < (len_sequence / num_stimuli) and count_0 < (len_sequence / num_stimuli) and count75_3 > 0 and count25_3 > 0:
                # randomly choose next stimulus based on our pre-defined probabilities:
                next_stimulus_index = random.choices([3,0], [.25, .75])[0]
                if next_stimulus_index == 0:
                  count75_3 = count75_3 - 1 # one less transition from 3 to 0 left - update counter!
                else:
                  count25_3 = count25_3 - 1 # one less transition from 3 to 3 left - update counter!
              else:
                # if we can't use stimulus 3 anymore and the transition to 0 is still allowed:
                if count_3 >= (len_sequence / num_stimuli) and count25_3 > 0:
                  #print("counter 3 reached the limit!")
                  next_stimulus_index = 0
                  count75_3 = count75_3 - 1  # one less transition from 3 to 0 left - update counter!
                # if we can't use stimulus 0 anymore and the transition to 3 is still allowed:
                elif count_0 >= (len_sequence / num_stimuli) and count75_3 > 0:
                  #print("counter 0 reached the limit!")
                  next_stimulus_index = 3
                  count25_3 = count25_3 - 1  # one less transition from 3 to 3 left - update counter!
                else:
                  print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
                  # couldn't find solution - recursion!
                  generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
            # update counter:
            if next_stimulus_index == 0:
              count_0 = count_0 + 1
            elif next_stimulus_index == 1:
              count_1 = count_1 + 1
            elif next_stimulus_index == 2:
              count_2 = count_2 + 1
            elif next_stimulus_index == 3:
              count_3 = count_3 + 1

            # update current stimulus based on next_stimulus_index
            current_stimulus = stimuli[next_stimulus_index]

            # append current stimulus to the sequence
            sequence.append(current_stimulus)
        print(len_sequence / num_stimuli)
        return sequence

    elif condition == "random":
      pass


tones = [440, 587, 782, 1043]
sequence_length = 1500

result_sequence = generate_sequence_from_matrix(condition = "ordered",stimuli = tones, len_sequence = 1504)
# --> with 1500 stimuli and 4 stimuli, you will never have non-float numbers for the absolute numbers of transitions, so
# by definition, the transition probabilities CAN'T match the 25% and 75% if we don't use
#a little more or a little less values.

#print(calculate_transition_probabilities(result_sequence))

print(result_sequence.count(440))
print(result_sequence.count(587))
print(result_sequence.count(782))
print(result_sequence.count(1043))

print(result_sequence.count(440) + result_sequence.count(587) + result_sequence.count(782) + result_sequence.count(1043))
# Out:
# 3: something odd is happening here: count 3: 362 count 0: 346 75: 15.0 25: 0.0
# 0: something odd is happening here: count 1:  312 count 0:  325 51.0 0.0
# 0: something odd is happening here: count 1:  304 count 0:  318 59.0 0.0
# 3: something odd is happening here: count 3: 330 count 0: 325 75: 47.0 25: 0.0
# 2: something odd is happening here: count 3:  301 count 2:  311 66.0 0.0
# 0: something odd is happening here: count 1:  332 count 0:  339 38.0 0.0
# 3: something odd is happening here: count 3: 326 count 0: 285 75: 50.0 25: 0.0
# 3: something odd is happening here: count 3: 355 count 0: 331 75: 22.0 25: 0.0
# 0: something odd is happening here: count 1:  306 count 0:  328 48.0 0.0
# 0: something odd is happening here: count 1:  352 count 0:  357 20.0 0.0
# 1: something odd is happening here: count 2:  342 count 1:  344 33.0 0.0
# 0: something odd is happening here: count 1:  364 count 0:  353 0.0 23.0
# 3: something odd is happening here: count 3: 325 count 0: 309 75: 52.0 25: 0.0
# 1: something odd is happening here: count 2:  362 count 1:  374 0.0 2.0
# 2: something odd is happening here: count 3:  331 count 2:  361 16.0 0.0
# 0: something odd is happening here: count 1:  326 count 0:  329 48.0 0.0
# 2: something odd is happening here: count 3:  370 count 2:  372 5.0 0.0
# 0: something odd is happening here: count 1:  289 count 0:  317 60.0 0.0
# 2: something odd is happening here: count 3:  305 count 2:  331 45.0 0.0
# 1: something odd is happening here: count 2:  362 count 1:  374 3.0 0.0
# 0: something odd is happening here: count 1:  361 count 0:  373 3.0 0.0
# 0: something odd is happening here: count 1:  331 count 0:  361 16.0 0.0
# 2: something odd is happening here: count 3:  344 count 2:  351 25.0 0.0
# 1: something odd is happening here: count 2:  326 count 1:  342 35.0 0.0
# 2: something odd is happening here: count 3:  305 count 2:  331 45.0 0.0
# 0: something odd is happening here: count 1:  331 count 0:  342 34.0 0.0
# 1: something odd is happening here: count 2:  320 count 1:  341 35.0 0.0
# 3: something odd is happening here: count 3: 322 count 0: 290 75: 54.0 25: 0.0
# 3: something odd is happening here: count 3: 333 count 0: 308 75: 43.0 25: 0.0
# 1: something odd is happening here: count 2:  315 count 1:  336 41.0 0.0
# 1: something odd is happening here: count 2:  300 count 1:  332 45.0 0.0
# 3: something odd is happening here: count 3: 360 count 0: 345 75: 17.0 25: 0.0
# 3: something odd is happening here: count 3: 325 count 0: 305 75: 52.0 25: 0.0
# 2: something odd is happening here: count 3:  276 count 2:  310 66.0 0.0
# 1: something odd is happening here: count 2:  340 count 1:  343 34.0 0.0
# 1: something odd is happening here: count 2:  309 count 1:  342 34.0 0.0
# 2: something odd is happening here: count 3:  318 count 2:  330 47.0 0.0
# 0: something odd is happening here: count 1:  318 count 0:  344 33.0 0.0
# 0: something odd is happening here: count 1:  338 count 0:  359 17.0 0.0
# 1: something odd is happening here: count 2:  339 count 1:  354 23.0 0.0
# 2: something odd is happening here: count 3:  277 count 2:  310 67.0 0.0
# 2: something odd is happening here: count 3:  285 count 2:  314 63.0 0.0
# 0: something odd is happening here: count 1:  298 count 0:  307 70.0 0.0
# 3: something odd is happening here: count 3: 299 count 0: 248 75: 78.0 25: 0.0
# 2: something odd is happening here: count 3:  367 count 2:  372 5.0 0.0
# 0: something odd is happening here: count 1:  287 count 0:  314 63.0 0.0
# 3: something odd is happening here: count 3: 347 count 0: 331 75: 30.0 25: 0.0
# 1: something odd is happening here: count 2:  366 count 1:  373 3.0 0.0
# 2: something odd is happening here: count 3:  326 count 2:  349 28.0 0.0
# 1: something odd is happening here: count 2:  353 count 1:  357 20.0 0.0
# 0: something odd is happening here: count 1:  263 count 0:  292 85.0 0.0
# 3: something odd is happening here: count 3: 363 count 0: 355 75: 14.0 25: 0.0
# 2: something odd is happening here: count 3:  299 count 2:  316 61.0 0.0
# 1: something odd is happening here: count 2:  333 count 1:  355 21.0 0.0
# 0: something odd is happening here: count 1:  311 count 0:  326 50.0 0.0
# 0: something odd is happening here: count 1:  290 count 0:  324 53.0 0.0
# 0: something odd is happening here: count 1:  276 count 0:  305 71.0 0.0
# 3: something odd is happening here: count 3: 352 count 0: 346 75: 25.0 25: 0.0
# 1: something odd is happening here: count 2:  344 count 1:  354 23.0 0.0
# 0: something odd is happening here: count 1:  331 count 0:  344 32.0 0.0
# 1: something odd is happening here: count 2:  352 count 1:  373 4.0 0.0
# 0: something odd is happening here: count 1:  234 count 0:  286 91.0 0.0
# 0: something odd is happening here: count 1:  291 count 0:  318 58.0 0.0
# 2: something odd is happening here: count 3:  337 count 2:  346 31.0 0.0
# 0: something odd is happening here: count 1:  273 count 0:  307 70.0 0.0
# 3: something odd is happening here: count 3: 349 count 0: 347 75: 28.0 25: 0.0
# 1: something odd is happening here: count 2:  293 count 1:  318 59.0 0.0
# 2: something odd is happening here: count 3:  300 count 2:  318 59.0 0.0
# 2: something odd is happening here: count 3:  374 count 2:  367 0.0 9.0
# 0: something odd is happening here: count 1:  374 count 0:  372 0.0 4.0
# 1: something odd is happening here: count 2:  288 count 1:  316 60.0 0.0
# 3: something odd is happening here: count 3: 329 count 0: 305 75: 47.0 25: 0.0
# 2: something odd is happening here: count 3:  362 count 2:  367 10.0 0.0
# 2: something odd is happening here: count 3:  315 count 2:  331 46.0 0.0
# 2: something odd is happening here: count 3:  289 count 2:  300 77.0 0.0
# 3: something odd is happening here: count 3: 305 count 0: 290 75: 72.0 25: 0.0
# 0: something odd is happening here: count 1:  330 count 0:  348 29.0 0.0
# 3: something odd is happening here: count 3: 330 count 0: 301 75: 46.0 25: 0.0
# 1: something odd is happening here: count 2:  356 count 1:  371 6.0 0.0
# 2: something odd is happening here: count 3:  331 count 2:  349 27.0 0.0
# 0: something odd is happening here: count 1:  264 count 0:  291 86.0 0.0
# 2: something odd is happening here: count 3:  327 count 2:  334 42.0 0.0
# 1: something odd is happening here: count 2:  301 count 1:  316 60.0 0.0
# 3: something odd is happening here: count 3: 326 count 0: 309 75: 51.0 25: 0.0
# 1: something odd is happening here: count 2:  282 count 1:  318 59.0 0.0
# 1: something odd is happening here: count 2:  316 count 1:  332 45.0 0.0
# 3: something odd is happening here: count 3: 375 count 0: 359 75: 0.0 25: 1.0
# 2: something odd is happening here: count 3:  348 count 2:  370 6.0 0.0
# 0: something odd is happening here: count 1:  314 count 0:  336 41.0 0.0
# 2: something odd is happening here: count 3:  350 count 2:  370 6.0 0.0
# 2: something odd is happening here: count 3:  364 count 2:  370 7.0 0.0
# 2: something odd is happening here: count 3:  279 count 2:  305 72.0 0.0
# 0: something odd is happening here: count 1:  306 count 0:  323 54.0 0.0
# 2: something odd is happening here: count 3:  360 count 2:  363 13.0 0.0
# 2: something odd is happening here: count 3:  321 count 2:  343 34.0 0.0
# 2: something odd is happening here: count 3:  355 count 2:  366 10.0 0.0
# 0: something odd is happening here: count 1:  318 count 0:  327 49.0 0.0
# 0: something odd is happening here: count 1:  326 count 0:  335 41.0 0.0
# 0: something odd is happening here: count 1:  361 count 0:  372 0.0 4.0
# 2: something odd is happening here: count 3:  371 count 2:  375 0.0 1.0
# 1: something odd is happening here: count 2:  332 count 1:  345 32.0 0.0
# 2: something odd is happening here: count 3:  344 count 2:  351 25.0 0.0
# 3: something odd is happening here: count 3: 341 count 0: 327 75: 36.0 25: 0.0
# 3: something odd is happening here: count 3: 324 count 0: 295 75: 53.0 25: 0.0
# 1: something odd is happening here: count 2:  324 count 1:  350 26.0 0.0
# 2: something odd is happening here: count 3:  354 count 2:  361 15.0 0.0
# 2: something odd is happening here: count 3:  297 count 2:  330 47.0 0.0
# 1: something odd is happening here: count 2:  324 count 1:  348 29.0 0.0
# 2: something odd is happening here: count 3:  358 count 2:  363 14.0 0.0
# 3: something odd is happening here: count 3: 328 count 0: 316 75: 49.0 25: 0.0
# 3: something odd is happening here: count 3: 357 count 0: 346 75: 20.0 25: 0.0
# 0: something odd is happening here: count 1:  338 count 0:  356 21.0 0.0
# 0: something odd is happening here: count 1:  354 count 0:  364 13.0 0.0
# 2: something odd is happening here: count 3:  292 count 2:  326 51.0 0.0
# 0: something odd is happening here: count 1:  355 count 0:  372 4.0 0.0
# 0: something odd is happening here: count 1:  361 count 0:  369 8.0 0.0
# 0: something odd is happening here: count 1:  347 count 0:  353 23.0 0.0
# 3: something odd is happening here: count 3: 328 count 0: 300 75: 49.0 25: 0.0
# 1: something odd is happening here: count 2:  299 count 1:  309 68.0 0.0
# 0: something odd is happening here: count 1:  324 count 0:  350 27.0 0.0
# 3: something odd is happening here: count 3: 343 count 0: 308 75: 34.0 25: 0.0
# 3: something odd is happening here: count 3: 343 count 0: 329 75: 33.0 25: 0.0
# 1: something odd is happening here: count 2:  342 count 1:  346 31.0 0.0
# 1: something odd is happening here: count 2:  340 count 1:  355 22.0 0.0
# 0: something odd is happening here: count 1:  349 count 0:  371 5.0 0.0
# 1: something odd is happening here: count 2:  296 count 1:  309 68.0 0.0
# 0: something odd is happening here: count 1:  305 count 0:  317 59.0 0.0
# 1: something odd is happening here: count 2:  351 count 1:  366 11.0 0.0
# 1: something odd is happening here: count 2:  342 count 1:  356 21.0 0.0
# 0: something odd is happening here: count 1:  297 count 0:  324 52.0 0.0
# 1: something odd is happening here: count 2:  323 count 1:  349 28.0 0.0
# 0: something odd is happening here: count 1:  331 count 0:  340 37.0 0.0
# 2: something odd is happening here: count 3:  300 count 2:  312 65.0 0.0
# 0: something odd is happening here: count 1:  374 count 0:  367 0.0 9.0
# 0: something odd is happening here: count 1:  348 count 0:  358 19.0 0.0
# 2: something odd is happening here: count 3:  317 count 2:  339 38.0 0.0
# 1: something odd is happening here: count 2:  339 count 1:  342 35.0 0.0
# 0: something odd is happening here: count 1:  330 count 0:  353 24.0 0.0
# 2: something odd is happening here: count 3:  305 count 2:  336 41.0 0.0
# 2: something odd is happening here: count 3:  353 count 2:  362 15.0 0.0
# 2: something odd is happening here: count 3:  289 count 2:  317 60.0 0.0
# 0: something odd is happening here: count 1:  327 count 0:  335 42.0 0.0
# 0: something odd is happening here: count 1:  361 count 0:  369 8.0 0.0
# 3: something odd is happening here: count 3: 342 count 0: 330 75: 34.0 25: 0.0
# 2: something odd is happening here: count 3:  306 count 2:  327 50.0 0.0
# 0: something odd is happening here: count 1:  276 count 0:  307 70.0 0.0
# 0: something odd is happening here: count 1:  315 count 0:  338 39.0 0.0
# 1: something odd is happening here: count 2:  297 count 1:  318 59.0 0.0
# 1: something odd is happening here: count 2:  280 count 1:  319 57.0 0.0
# 2: something odd is happening here: count 3:  321 count 2:  347 30.0 0.0
# 0: something odd is happening here: count 1:  329 count 0:  341 36.0 0.0
# 3: something odd is happening here: count 3: 327 count 0: 312 75: 50.0 25: 0.0
# 0: something odd is happening here: count 1:  369 count 0:  374 3.0 0.0
# 3: something odd is happening here: count 3: 362 count 0: 361 75: 14.0 25: 0.0
# 3: something odd is happening here: count 3: 353 count 0: 335 75: 23.0 25: 0.0
# 1: something odd is happening here: count 2:  321 count 1:  335 42.0 0.0
# 2: something odd is happening here: count 3:  322 count 2:  343 33.0 0.0
# 0: something odd is happening here: count 1:  264 count 0:  287 90.0 0.0
# 3: something odd is happening here: count 3: 357 count 0: 349 75: 19.0 25: 0.0
# 3: something odd is happening here: count 3: 329 count 0: 305 75: 48.0 25: 0.0
# 0: something odd is happening here: count 1:  302 count 0:  313 63.0 0.0
# 0: something odd is happening here: count 1:  305 count 0:  324 52.0 0.0
# 1: something odd is happening here: count 2:  309 count 1:  329 48.0 0.0
# 1: something odd is happening here: count 2:  338 count 1:  355 22.0 0.0
# 0: something odd is happening here: count 1:  354 count 0:  372 5.0 0.0
# 1: something odd is happening here: count 2:  300 count 1:  316 61.0 0.0
# 0: something odd is happening here: count 1:  368 count 0:  348 0.0 28.0
# 3: something odd is happening here: count 3: 350 count 0: 328 75: 27.0 25: 0.0
# 3: something odd is happening here: count 3: 358 count 0: 350 75: 19.0 25: 0.0
# 1: something odd is happening here: count 2:  360 count 1:  366 11.0 0.0
# 2: something odd is happening here: count 3:  361 count 2:  375 0.0 1.0
# 0: something odd is happening here: count 1:  303 count 0:  339 38.0 0.0
# 3: something odd is happening here: count 3: 366 count 0: 353 75: 11.0 25: 0.0
# 0: something odd is happening here: count 1:  319 count 0:  341 35.0 0.0
# 1: something odd is happening here: count 2:  334 count 1:  346 30.0 0.0
# 1: something odd is happening here: count 2:  290 count 1:  316 60.0 0.0
# 3: something odd is happening here: count 3: 344 count 0: 329 75: 33.0 25: 0.0
# 2: something odd is happening here: count 3:  354 count 2:  356 21.0 0.0
# 3: something odd is happening here: count 3: 354 count 0: 352 75: 23.0 25: 0.0
# 1: something odd is happening here: count 2:  335 count 1:  354 23.0 0.0
# 1: something odd is happening here: count 2:  312 count 1:  323 54.0 0.0
# 1: something odd is happening here: count 2:  307 count 1:  311 66.0 0.0
# 0: something odd is happening here: count 1:  342 count 0:  356 21.0 0.0
# 1: something odd is happening here: count 2:  312 count 1:  336 41.0 0.0
# 2: something odd is happening here: count 3:  318 count 2:  331 45.0 0.0
# 3: something odd is happening here: count 3: 347 count 0: 318 75: 30.0 25: 0.0
# 1: something odd is happening here: count 2:  317 count 1:  334 42.0 0.0
# 1: something odd is happening here: count 2:  292 count 1:  315 61.0 0.0
# 0: something odd is happening here: count 1:  351 count 0:  368 8.0 0.0
# 1: something odd is happening here: count 2:  332 count 1:  359 17.0 0.0
# 1: something odd is happening here: count 2:  327 count 1:  347 29.0 0.0
# 2: something odd is happening here: count 3:  328 count 2:  343 34.0 0.0
# 1: something odd is happening here: count 2:  249 count 1:  300 76.0 0.0
# 2: something odd is happening here: count 3:  296 count 2:  322 55.0 0.0
# 0: something odd is happening here: count 1:  295 count 0:  328 49.0 0.0
# 3: something odd is happening here: count 3: 371 count 0: 366 75: 6.0 25: 0.0
# 0: something odd is happening here: count 1:  322 count 0:  328 48.0 0.0
# 3: something odd is happening here: count 3: 350 count 0: 338 75: 27.0 25: 0.0
# 3: something odd is happening here: count 3: 333 count 0: 319 75: 43.0 25: 0.0
# 3: something odd is happening here: count 3: 343 count 0: 321 75: 34.0 25: 0.0
# 0: something odd is happening here: count 1:  303 count 0:  332 44.0 0.0
# 0: something odd is happening here: count 1:  364 count 0:  374 2.0 0.0
# 0: something odd is happening here: count 1:  342 count 0:  349 28.0 0.0
# 3: something odd is happening here: count 3: 298 count 0: 261 75: 78.0 25: 0.0
# 0: something odd is happening here: count 1:  321 count 0:  332 44.0 0.0
# 3: something odd is happening here: count 3: 346 count 0: 326 75: 31.0 25: 0.0
# 1: something odd is happening here: count 2:  332 count 1:  339 38.0 0.0
# 2: something odd is happening here: count 3:  314 count 2:  319 58.0 0.0
# 2: something odd is happening here: count 3:  361 count 2:  374 0.0 2.0
# 3: something odd is happening here: count 3: 375 count 0: 371 75: 2.0 25: 0.0
# 2: something odd is happening here: count 3:  316 count 2:  335 42.0 0.0
# 1: something odd is happening here: count 2:  320 count 1:  349 28.0 0.0
# 1: something odd is happening here: count 2:  304 count 1:  321 55.0 0.0
# 3: something odd is happening here: count 3: 356 count 0: 347 75: 21.0 25: 0.0
# 3: something odd is happening here: count 3: 325 count 0: 310 75: 52.0 25: 0.0
# 1: something odd is happening here: count 2:  328 count 1:  338 39.0 0.0
# 0: something odd is happening here: count 1:  326 count 0:  339 38.0 0.0
# 2: something odd is happening here: count 3:  314 count 2:  326 51.0 0.0
# 2: something odd is happening here: count 3:  342 count 2:  352 25.0 0.0
# 2: something odd is happening here: count 3:  346 count 2:  355 22.0 0.0
# 2: something odd is happening here: count 3:  311 count 2:  331 46.0 0.0
# 2: something odd is happening here: count 3:  344 count 2:  353 24.0 0.0
# 3: something odd is happening here: count 3: 331 count 0: 298 75: 45.0 25: 0.0
# 1: something odd is happening here: count 2:  271 count 1:  308 68.0 0.0
# 0: something odd is happening here: count 1:  354 count 0:  376 1.0 0.0
# 0: something odd is happening here: count 1:  312 count 0:  328 49.0 0.0
# 3: something odd is happening here: count 3: 375 count 0: 348 75: 2.0 25: 0.0
# 1: something odd is happening here: count 2:  344 count 1:  356 21.0 0.0
# 2: something odd is happening here: count 3:  337 count 2:  353 24.0 0.0
# 1: something odd is happening here: count 2:  319 count 1:  332 45.0 0.0
# 2: something odd is happening here: count 3:  301 count 2:  332 45.0 0.0
# 3: something odd is happening here: count 3: 345 count 0: 330 75: 32.0 25: 0.0
# 3: something odd is happening here: count 3: 302 count 0: 265 75: 75.0 25: 0.0
# 3: something odd is happening here: count 3: 374 count 0: 365 75: 0.0 25: 2.0
# 2: something odd is happening here: count 3:  360 count 2:  366 0.0 10.0
# 2: something odd is happening here: count 3:  347 count 2:  355 22.0 0.0
# 2: something odd is happening here: count 3:  335 count 2:  349 28.0 0.0
# 3: something odd is happening here: count 3: 364 count 0: 361 75: 13.0 25: 0.0
# 2: something odd is happening here: count 3:  305 count 2:  322 55.0 0.0
# 1: something odd is happening here: count 2:  310 count 1:  342 34.0 0.0
# 0: something odd is happening here: count 1:  350 count 0:  366 10.0 0.0
# 0: something odd is happening here: count 1:  328 count 0:  331 46.0 0.0
# 1: something odd is happening here: count 2:  357 count 1:  367 0.0 9.0
# 0: something odd is happening here: count 1:  302 count 0:  332 45.0 0.0
# 2: something odd is happening here: count 3:  305 count 2:  325 52.0 0.0
# 2: something odd is happening here: count 3:  343 count 2:  364 13.0 0.0
# 2: something odd is happening here: count 3:  339 count 2:  353 24.0 0.0
# 2: something odd is happening here: count 3:  354 count 2:  371 6.0 0.0
# 0: something odd is happening here: count 1:  284 count 0:  302 75.0 0.0
# 0: something odd is happening here: count 1:  311 count 0:  339 38.0 0.0
# 2: something odd is happening here: count 3:  266 count 2:  297 79.0 0.0
# 0: something odd is happening here: count 1:  331 count 0:  344 33.0 0.0
# 3: something odd is happening here: count 3: 367 count 0: 364 75: 10.0 25: 0.0
# 3: something odd is happening here: count 3: 351 count 0: 335 75: 25.0 25: 0.0
# 1: something odd is happening here: count 2:  373 count 1:  363 0.0 13.0
# 1: something odd is happening here: count 2:  288 count 1:  315 62.0 0.0
# 1: something odd is happening here: count 2:  358 count 1:  362 14.0 0.0
# 1: something odd is happening here: count 2:  310 count 1:  318 58.0 0.0
# 2: something odd is happening here: count 3:  340 count 2:  356 21.0 0.0
# 3: something odd is happening here: count 3: 365 count 0: 357 75: 12.0 25: 0.0
# 3: something odd is happening here: count 3: 324 count 0: 322 75: 53.0 25: 0.0
# 0: something odd is happening here: count 1:  290 count 0:  314 62.0 0.0
# 2: something odd is happening here: count 3:  330 count 2:  338 39.0 0.0
# 1: something odd is happening here: count 2:  351 count 1:  367 9.0 0.0
# 2: something odd is happening here: count 3:  336 count 2:  348 29.0 0.0
# 0: something odd is happening here: count 1:  365 count 0:  364 0.0 12.0
# 0: something odd is happening here: count 1:  324 count 0:  346 31.0 0.0
# 3: something odd is happening here: count 3: 351 count 0: 344 75: 25.0 25: 0.0
# 0: something odd is happening here: count 1:  360 count 0:  365 12.0 0.0
# 2: something odd is happening here: count 3:  263 count 2:  300 76.0 0.0
# 2: something odd is happening here: count 3:  295 count 2:  316 60.0 0.0
# 0: something odd is happening here: count 1:  317 count 0:  335 41.0 0.0
# 1: something odd is happening here: count 2:  331 count 1:  364 13.0 0.0
# 3: something odd is happening here: count 3: 367 count 0: 363 75: 0.0 25: 9.0
# 0: something odd is happening here: count 1:  273 count 0:  311 65.0 0.0
# 3: something odd is happening here: count 3: 344 count 0: 342 75: 33.0 25: 0.0
# 1: something odd is happening here: count 2:  355 count 1:  357 20.0 0.0
# 1: something odd is happening here: count 2:  361 count 1:  362 0.0 14.0
# 1: something odd is happening here: count 2:  333 count 1:  338 38.0 0.0
# 1: something odd is happening here: count 2:  335 count 1:  359 18.0 0.0
# 1: something odd is happening here: count 2:  315 count 1:  339 38.0 0.0
# 0: something odd is happening here: count 1:  331 count 0:  339 37.0 0.0
# 3: something odd is happening here: count 3: 325 count 0: 318 75: 51.0 25: 0.0
# 3: something odd is happening here: count 3: 366 count 0: 358 75: 0.0 25: 10.0
# 1: something odd is happening here: count 2:  361 count 1:  366 10.0 0.0
# 1: something odd is happening here: count 2:  338 count 1:  349 28.0 0.0
# 3: something odd is happening here: count 3: 292 count 0: 249 75: 84.0 25: 0.0
# 1: something odd is happening here: count 2:  316 count 1:  332 44.0 0.0
# 0: something odd is happening here: count 1:  339 count 0:  350 27.0 0.0
# 3: something odd is happening here: count 3: 368 count 0: 352 75: 9.0 25: 0.0
# 2: something odd is happening here: count 3:  332 count 2:  358 19.0 0.0
# 2: something odd is happening here: count 3:  300 count 2:  329 47.0 0.0
# 1: something odd is happening here: count 2:  327 count 1:  340 36.0 0.0
# 0: something odd is happening here: count 1:  275 count 0:  308 68.0 0.0
# 0: something odd is happening here: count 1:  262 count 0:  290 86.0 0.0
# 2: something odd is happening here: count 3:  258 count 2:  288 89.0 0.0
# 3: something odd is happening here: count 3: 353 count 0: 334 75: 24.0 25: 0.0
# 2: something odd is happening here: count 3:  351 count 2:  354 23.0 0.0
# 3: something odd is happening here: count 3: 363 count 0: 356 75: 14.0 25: 0.0
# 3: something odd is happening here: count 3: 336 count 0: 304 75: 41.0 25: 0.0
# 0: something odd is happening here: count 1:  358 count 0:  371 6.0 0.0
# 0: something odd is happening here: count 1:  302 count 0:  324 52.0 0.0
# 2: something odd is happening here: count 3:  312 count 2:  330 47.0 0.0
# 0: something odd is happening here: count 1:  345 count 0:  359 18.0 0.0
# 3: something odd is happening here: count 3: 343 count 0: 330 75: 34.0 25: 0.0
# 0: something odd is happening here: count 1:  304 count 0:  329 47.0 0.0
# 3: something odd is happening here: count 3: 376 count 0: 365 75: 1.0 25: 0.0
# 3: something odd is happening here: count 3: 334 count 0: 324 75: 42.0 25: 0.0
# 3: something odd is happening here: count 3: 343 count 0: 332 75: 34.0 25: 0.0
# 3: something odd is happening here: count 3: 373 count 0: 363 75: 4.0 25: 0.0
# 1: something odd is happening here: count 2:  310 count 1:  332 45.0 0.0
# 0: something odd is happening here: count 1:  349 count 0:  355 22.0 0.0
# 2: something odd is happening here: count 3:  293 count 2:  327 49.0 0.0
# 2: something odd is happening here: count 3:  312 count 2:  331 46.0 0.0
# 2: something odd is happening here: count 3:  302 count 2:  339 37.0 0.0
# 3: something odd is happening here: count 3: 322 count 0: 280 75: 55.0 25: 0.0
# 1: something odd is happening here: count 2:  360 count 1:  372 5.0 0.0
# 1: something odd is happening here: count 2:  287 count 1:  314 63.0 0.0
# 3: something odd is happening here: count 3: 343 count 0: 316 75: 34.0 25: 0.0
# 1: something odd is happening here: count 2:  299 count 1:  318 59.0 0.0
# 1: something odd is happening here: count 2:  368 count 1:  373 4.0 0.0
# 1: something odd is happening here: count 2:  312 count 1:  334 42.0 0.0
# 1: something odd is happening here: count 2:  270 count 1:  308 69.0 0.0
# 0: something odd is happening here: count 1:  331 count 0:  333 44.0 0.0
# 0: something odd is happening here: count 1:  312 count 0:  326 51.0 0.0
# 1: something odd is happening here: count 2:  317 count 1:  342 34.0 0.0
# 2: something odd is happening here: count 3:  338 count 2:  342 35.0 0.0
# 0: something odd is happening here: count 1:  348 count 0:  356 20.0 0.0
# 3: something odd is happening here: count 3: 366 count 0: 363 75: 10.0 25: 0.0
# 2: something odd is happening here: count 3:  307 count 2:  326 51.0 0.0
# 3: something odd is happening here: count 3: 328 count 0: 305 75: 49.0 25: 0.0
# 0: something odd is happening here: count 1:  309 count 0:  331 45.0 0.0
# 2: something odd is happening here: count 3:  334 count 2:  358 19.0 0.0
# 3: something odd is happening here: count 3: 321 count 0: 287 75: 56.0 25: 0.0
# 0: something odd is happening here: count 1:  329 count 0:  340 37.0 0.0
# 3: something odd is happening here: count 3: 347 count 0: 346 75: 29.0 25: 0.0
# 3: something odd is happening here: count 3: 371 count 0: 357 75: 6.0 25: 0.0
# 0: something odd is happening here: count 1:  359 count 0:  367 10.0 0.0
# 1: something odd is happening here: count 2:  270 count 1:  306 71.0 0.0
# 0: something odd is happening here: count 1:  335 count 0:  341 35.0 0.0
# 0: something odd is happening here: count 1:  338 count 0:  353 24.0 0.0
# 0: something odd is happening here: count 1:  370 count 0:  372 5.0 0.0
# 3: something odd is happening here: count 3: 320 count 0: 299 75: 56.0 25: 0.0
# 3: something odd is happening here: count 3: 365 count 0: 343 75: 11.0 25: 0.0
# 0: something odd is happening here: count 1:  361 count 0:  365 12.0 0.0
# 0: something odd is happening here: count 1:  346 count 0:  370 7.0 0.0
# 2: something odd is happening here: count 3:  298 count 2:  336 41.0 0.0
# 2: something odd is happening here: count 3:  338 count 2:  345 32.0 0.0
# 1: something odd is happening here: count 2:  368 count 1:  372 5.0 0.0
# 0: something odd is happening here: count 1:  327 count 0:  350 27.0 0.0
# 1: something odd is happening here: count 2:  306 count 1:  335 42.0 0.0
# 2: something odd is happening here: count 3:  335 count 2:  354 23.0 0.0
# 2: something odd is happening here: count 3:  330 count 2:  345 32.0 0.0
# 0: something odd is happening here: count 1:  323 count 0:  332 45.0 0.0
# 0: something odd is happening here: count 1:  308 count 0:  332 44.0 0.0
# 0: something odd is happening here: count 1:  297 count 0:  337 40.0 0.0
# 0: something odd is happening here: count 1:  322 count 0:  332 45.0 0.0
# 2: something odd is happening here: count 3:  264 count 2:  297 80.0 0.0
# 3: something odd is happening here: count 3: 349 count 0: 321 75: 27.0 25: 0.0
# 0: something odd is happening here: count 1:  363 count 0:  363 0.0 13.0
# 0: something odd is happening here: count 1:  319 count 0:  324 52.0 0.0
# 3: something odd is happening here: count 3: 338 count 0: 319 75: 39.0 25: 0.0
# 2: something odd is happening here: count 3:  370 count 2:  367 0.0 9.0
# 3: something odd is happening here: count 3: 304 count 0: 267 75: 73.0 25: 0.0
# 2: something odd is happening here: count 3:  334 count 2:  346 31.0 0.0
# 1: something odd is happening here: count 2:  351 count 1:  356 20.0 0.0
# 3: something odd is happening here: count 3: 331 count 0: 307 75: 46.0 25: 0.0
# 0: something odd is happening here: count 1:  286 count 0:  299 78.0 0.0
# 3: something odd is happening here: count 3: 332 count 0: 315 75: 44.0 25: 0.0
# 3: something odd is happening here: count 3: 350 count 0: 324 75: 26.0 25: 0.0
# 1: something odd is happening here: count 2:  374 count 1:  372 0.0 4.0
# 0: something odd is happening here: count 1:  305 count 0:  313 63.0 0.0
# 2: something odd is happening here: count 3:  270 count 2:  303 73.0 0.0
# 0: something odd is happening here: count 1:  305 count 0:  310 67.0 0.0
# 2: something odd is happening here: count 3:  373 count 2:  367 0.0 9.0
# 3: something odd is happening here: count 3: 337 count 0: 321 75: 40.0 25: 0.0
# 3: something odd is happening here: count 3: 351 count 0: 339 75: 26.0 25: 0.0
# 2: something odd is happening here: count 3:  281 count 2:  310 67.0 0.0
# 3: something odd is happening here: count 3: 352 count 0: 340 75: 24.0 25: 0.0
# 0: something odd is happening here: count 1:  350 count 0:  352 24.0 0.0
# 2: something odd is happening here: count 3:  340 count 2:  351 26.0 0.0
# 1: something odd is happening here: count 2:  307 count 1:  331 46.0 0.0
# 3: something odd is happening here: count 3: 348 count 0: 342 75: 29.0 25: 0.0
# 1: something odd is happening here: count 2:  322 count 1:  339 38.0 0.0
# 3: something odd is happening here: count 3: 344 count 0: 332 75: 33.0 25: 0.0
# 0: something odd is happening here: count 1:  344 count 0:  350 27.0 0.0
# 2: something odd is happening here: count 3:  323 count 2:  353 23.0 0.0
# 0: something odd is happening here: count 1:  344 count 0:  352 25.0 0.0
# 3: something odd is happening here: count 3: 361 count 0: 351 75: 16.0 25: 0.0
# 2: something odd is happening here: count 3:  331 count 2:  355 22.0 0.0
# 1: something odd is happening here: count 2:  323 count 1:  348 29.0 0.0
# 3: something odd is happening here: count 3: 321 count 0: 297 75: 56.0 25: 0.0
# 2: something odd is happening here: count 3:  316 count 2:  335 42.0 0.0
# 1: something odd is happening here: count 2:  322 count 1:  350 27.0 0.0
# 0: something odd is happening here: count 1:  321 count 0:  337 40.0 0.0
# 0: something odd is happening here: count 1:  279 count 0:  301 75.0 0.0
# 0: something odd is happening here: count 1:  363 count 0:  366 11.0 0.0
# 0: something odd is happening here: count 1:  339 count 0:  363 14.0 0.0
# 3: something odd is happening here: count 3: 347 count 0: 342 75: 30.0 25: 0.0
# 3: something odd is happening here: count 3: 317 count 0: 301 75: 60.0 25: 0.0
# 3: something odd is happening here: count 3: 357 count 0: 339 75: 20.0 25: 0.0
# 2: something odd is happening here: count 3:  350 count 2:  358 19.0 0.0
# 0: something odd is happening here: count 1:  312 count 0:  335 42.0 0.0
# 3: something odd is happening here: count 3: 341 count 0: 331 75: 36.0 25: 0.0
# 1: something odd is happening here: count 2:  336 count 1:  356 21.0 0.0
# 3: something odd is happening here: count 3: 335 count 0: 321 75: 42.0 25: 0.0
# 0: something odd is happening here: count 1:  367 count 0:  370 7.0 0.0
# 0: something odd is happening here: count 1:  303 count 0:  314 63.0 0.0
# 3: something odd is happening here: count 3: 338 count 0: 324 75: 38.0 25: 0.0
# 2: something odd is happening here: count 3:  356 count 2:  363 13.0 0.0
# 0: something odd is happening here: count 1:  323 count 0:  339 37.0 0.0
# 0: something odd is happening here: count 1:  301 count 0:  320 57.0 0.0
# 1: something odd is happening here: count 2:  354 count 1:  372 5.0 0.0
# 0: something odd is happening here: count 1:  338 count 0:  346 30.0 0.0
# 1: something odd is happening here: count 2:  226 count 1:  262 115.0 0.0
# 0: something odd is happening here: count 1:  359 count 0:  367 10.0 0.0
# 2: something odd is happening here: count 3:  374 count 2:  364 0.0 12.0
# 2: something odd is happening here: count 3:  345 count 2:  359 18.0 0.0
# 2: something odd is happening here: count 3:  340 count 2:  351 26.0 0.0
# 1: something odd is happening here: count 2:  335 count 1:  351 26.0 0.0
# 2: something odd is happening here: count 3:  273 count 2:  310 67.0 0.0
# 2: something odd is happening here: count 3:  360 count 2:  364 13.0 0.0
# 1: something odd is happening here: count 2:  345 count 1:  367 9.0 0.0
# 2: something odd is happening here: count 3:  290 count 2:  314 63.0 0.0
# 3: something odd is happening here: count 3: 357 count 0: 348 75: 20.0 25: 0.0
# 3: something odd is happening here: count 3: 359 count 0: 375 75: 0.0 25: 17.0
# 0: something odd is happening here: count 1:  315 count 0:  342 35.0 0.0
# 3: something odd is happening here: count 3: 329 count 0: 315 75: 48.0 25: 0.0
# 1: something odd is happening here: count 2:  359 count 1:  372 0.0 4.0
# 1: something odd is happening here: count 2:  345 count 1:  354 22.0 0.0
# 2: something odd is happening here: count 3:  348 count 2:  358 19.0 0.0
# 0: something odd is happening here: count 1:  330 count 0:  339 38.0 0.0
# 0: something odd is happening here: count 1:  293 count 0:  325 52.0 0.0
# 1: something odd is happening here: count 2:  370 count 1:  363 0.0 13.0
# 1: something odd is happening here: count 2:  372 count 1:  361 0.0 15.0
# 2: something odd is happening here: count 3:  339 count 2:  348 29.0 0.0
# 1: something odd is happening here: count 2:  355 count 1:  358 18.0 0.0
# 3: something odd is happening here: count 3: 343 count 0: 341 75: 34.0 25: 0.0
# 0: something odd is happening here: count 1:  304 count 0:  325 52.0 0.0
# 2: something odd is happening here: count 3:  262 count 2:  296 81.0 0.0
# 2: something odd is happening here: count 3:  315 count 2:  344 33.0 0.0
# 2: something odd is happening here: count 3:  323 count 2:  350 26.0 0.0
# 2: something odd is happening here: count 3:  301 count 2:  340 37.0 0.0
# 2: something odd is happening here: count 3:  339 count 2:  346 31.0 0.0
# 0: something odd is happening here: count 1:  327 count 0:  335 42.0 0.0
# 1: something odd is happening here: count 2:  308 count 1:  335 42.0 0.0
# 1: something odd is happening here: count 2:  355 count 1:  358 19.0 0.0
# 2: something odd is happening here: count 3:  358 count 2:  373 0.0 3.0
# 2: something odd is happening here: count 3:  353 count 2:  357 20.0 0.0
# 1: something odd is happening here: count 2:  353 count 1:  354 22.0 0.0
# 1: something odd is happening here: count 2:  305 count 1:  329 48.0 0.0
# 0: something odd is happening here: count 1:  282 count 0:  307 69.0 0.0
# 1: something odd is happening here: count 2:  313 count 1:  328 48.0 0.0
# 3: something odd is happening here: count 3: 353 count 0: 347 75: 23.0 25: 0.0
# 2: something odd is happening here: count 3:  333 count 2:  345 32.0 0.0
# 1: something odd is happening here: count 2:  362 count 1:  365 12.0 0.0
# 0: something odd is happening here: count 1:  280 count 0:  309 67.0 0.0
# 3: something odd is happening here: count 3: 365 count 0: 350 75: 12.0 25: 0.0
# 2: something odd is happening here: count 3:  320 count 2:  338 39.0 0.0
# 2: something odd is happening here: count 3:  271 count 2:  294 83.0 0.0
# 3: something odd is happening here: count 3: 333 count 0: 310 75: 44.0 25: 0.0
# 1: something odd is happening here: count 2:  358 count 1:  363 14.0 0.0
# 3: something odd is happening here: count 3: 303 count 0: 289 75: 74.0 25: 0.0
# 0: something odd is happening here: count 1:  351 count 0:  366 11.0 0.0
# 0: something odd is happening here: count 1:  307 count 0:  330 47.0 0.0
# 0: something odd is happening here: count 1:  304 count 0:  321 55.0 0.0
# 3: something odd is happening here: count 3: 334 count 0: 322 75: 43.0 25: 0.0
# 3: something odd is happening here: count 3: 331 count 0: 322 75: 46.0 25: 0.0
# 0: something odd is happening here: count 1:  355 count 0:  364 13.0 0.0
# 0: something odd is happening here: count 1:  311 count 0:  327 50.0 0.0
# 3: something odd is happening here: count 3: 338 count 0: 315 75: 39.0 25: 0.0
# 3: something odd is happening here: count 3: 350 count 0: 339 75: 26.0 25: 0.0
# 3: something odd is happening here: count 3: 369 count 0: 361 75: 0.0 25: 7.0
# 2: something odd is happening here: count 3:  341 count 2:  349 28.0 0.0
# 0: something odd is happening here: count 1:  324 count 0:  338 39.0 0.0
# 2: something odd is happening here: count 3:  288 count 2:  315 62.0 0.0
# 1: something odd is happening here: count 2:  316 count 1:  323 54.0 0.0
# 1: something odd is happening here: count 2:  355 count 1:  374 0.0 2.0
# 2: something odd is happening here: count 3:  291 count 2:  311 66.0 0.0
# 1: something odd is happening here: count 2:  319 count 1:  337 40.0 0.0
# 1: something odd is happening here: count 2:  322 count 1:  345 32.0 0.0
# 3: something odd is happening here: count 3: 321 count 0: 280 75: 55.0 25: 0.0
# 3: something odd is happening here: count 3: 326 count 0: 298 75: 51.0 25: 0.0
# 0: something odd is happening here: count 1:  339 count 0:  341 36.0 0.0
# 0: something odd is happening here: count 1:  268 count 0:  299 77.0 0.0
# 2: something odd is happening here: count 3:  314 count 2:  329 48.0 0.0
# 0: something odd is happening here: count 1:  309 count 0:  326 50.0 0.0
# 1: something odd is happening here: count 2:  363 count 1:  372 5.0 0.0
# 2: something odd is happening here: count 3:  315 count 2:  336 41.0 0.0
# 0: something odd is happening here: count 1:  367 count 0:  375 2.0 0.0
# 1: something odd is happening here: count 2:  308 count 1:  331 46.0 0.0
# 0: something odd is happening here: count 1:  373 count 0:  369 0.0 7.0
# 3: something odd is happening here: count 3: 348 count 0: 335 75: 29.0 25: 0.0
# 0: something odd is happening here: count 1:  323 count 0:  339 38.0 0.0
# 1: something odd is happening here: count 2:  308 count 1:  323 54.0 0.0
# 0: something odd is happening here: count 1:  282 count 0:  308 69.0 0.0
# 2: something odd is happening here: count 3:  372 count 2:  366 0.0 10.0
# 0: something odd is happening here: count 1:  307 count 0:  325 52.0 0.0
# 0: something odd is happening here: count 1:  333 count 0:  339 38.0 0.0
# 3: something odd is happening here: count 3: 370 count 0: 363 75: 7.0 25: 0.0
# 2: something odd is happening here: count 3:  316 count 2:  322 55.0 0.0
# 3: something odd is happening here: count 3: 374 count 0: 356 75: 3.0 25: 0.0
# 0: something odd is happening here: count 1:  361 count 0:  375 0.0 1.0
# 1: something odd is happening here: count 2:  372 count 1:  359 0.0 17.0
# 3: something odd is happening here: count 3: 367 count 0: 361 75: 0.0 25: 9.0
# 1: something odd is happening here: count 2:  343 count 1:  357 20.0 0.0
# 3: something odd is happening here: count 3: 345 count 0: 341 75: 32.0 25: 0.0
# 0: something odd is happening here: count 1:  302 count 0:  325 52.0 0.0
# 0: something odd is happening here: count 1:  335 count 0:  339 37.0 0.0
# 1: something odd is happening here: count 2:  331 count 1:  341 35.0 0.0
# 1: something odd is happening here: count 2:  324 count 1:  334 43.0 0.0
# 0: something odd is happening here: count 1:  350 count 0:  355 22.0 0.0
# 3: something odd is happening here: count 3: 298 count 0: 263 75: 79.0 25: 0.0
# 3: something odd is happening here: count 3: 327 count 0: 301 75: 49.0 25: 0.0
# 1: something odd is happening here: count 2:  372 count 1:  375 2.0 0.0
# 1: something odd is happening here: count 2:  303 count 1:  325 52.0 0.0
# 0: something odd is happening here: count 1:  283 count 0:  315 62.0 0.0
# 1: something odd is happening here: count 2:  304 count 1:  317 60.0 0.0
# 2: something odd is happening here: count 3:  273 count 2:  301 76.0 0.0
# 1: something odd is happening here: count 2:  323 count 1:  341 36.0 0.0
# 2: something odd is happening here: count 3:  346 count 2:  361 16.0 0.0
# 3: something odd is happening here: count 3: 354 count 0: 345 75: 23.0 25: 0.0
# 2: something odd is happening here: count 3:  272 count 2:  302 74.0 0.0
# 2: something odd is happening here: count 3:  332 count 2:  341 36.0 0.0
# 1: something odd is happening here: count 2:  353 count 1:  356 21.0 0.0
# 2: something odd is happening here: count 3:  338 count 2:  351 26.0 0.0
# 3: something odd is happening here: count 3: 345 count 0: 332 75: 31.0 25: 0.0
# 3: something odd is happening here: count 3: 369 count 0: 366 75: 8.0 25: 0.0
# 0: something odd is happening here: count 1:  334 count 0:  337 40.0 0.0
# 1: something odd is happening here: count 2:  294 count 1:  324 53.0 0.0
# 0: something odd is happening here: count 1:  306 count 0:  329 48.0 0.0
# 1: something odd is happening here: count 2:  313 count 1:  328 49.0 0.0
# 0: something odd is happening here: count 1:  303 count 0:  323 54.0 0.0
# 3: something odd is happening here: count 3: 351 count 0: 346 75: 25.0 25: 0.0
# 3: something odd is happening here: count 3: 359 count 0: 339 75: 18.0 25: 0.0
# 0: something odd is happening here: count 1:  358 count 0:  360 17.0 0.0
# 1: something odd is happening here: count 2:  304 count 1:  329 48.0 0.0
# 1: something odd is happening here: count 2:  333 count 1:  357 20.0 0.0
# 1: something odd is happening here: count 2:  338 count 1:  352 25.0 0.0
# 2: something odd is happening here: count 3:  324 count 2:  333 44.0 0.0
# 0: something odd is happening here: count 1:  312 count 0:  343 34.0 0.0
# 2: something odd is happening here: count 3:  334 count 2:  347 30.0 0.0
# 1: something odd is happening here: count 2:  355 count 1:  359 18.0 0.0
# 1: something odd is happening here: count 2:  286 count 1:  309 68.0 0.0
# 1: something odd is happening here: count 2:  367 count 1:  374 3.0 0.0
# 0: something odd is happening here: count 1:  347 count 0:  360 17.0 0.0
# 2: something odd is happening here: count 3:  317 count 2:  324 53.0 0.0
# 2: something odd is happening here: count 3:  311 count 2:  333 44.0 0.0
# 0: something odd is happening here: count 1:  338 count 0:  350 26.0 0.0
# 0: something odd is happening here: count 1:  300 count 0:  327 50.0 0.0
# 3: something odd is happening here: count 3: 369 count 0: 361 75: 0.0 25: 7.0
# 0: something odd is happening here: count 1:  313 count 0:  336 41.0 0.0
# 0: something odd is happening here: count 1:  345 count 0:  353 24.0 0.0
# 1: something odd is happening here: count 2:  321 count 1:  335 42.0 0.0
# 1: something odd is happening here: count 2:  315 count 1:  344 32.0 0.0
# 3: something odd is happening here: count 3: 317 count 0: 290 75: 60.0 25: 0.0
# 1: something odd is happening here: count 2:  341 count 1:  350 27.0 0.0
# 0: something odd is happening here: count 1:  322 count 0:  342 35.0 0.0
# 3: something odd is happening here: count 3: 357 count 0: 344 75: 20.0 25: 0.0
# 3: something odd is happening here: count 3: 343 count 0: 320 75: 33.0 25: 0.0
# 0: something odd is happening here: count 1:  291 count 0:  307 70.0 0.0
# 3: something odd is happening here: count 3: 372 count 0: 368 75: 5.0 25: 0.0
# 3: something odd is happening here: count 3: 349 count 0: 320 75: 28.0 25: 0.0
# 1: something odd is happening here: count 2:  314 count 1:  324 53.0 0.0
# 1: something odd is happening here: count 2:  340 count 1:  351 25.0 0.0
# 2: something odd is happening here: count 3:  311 count 2:  344 33.0 0.0
# 1: something odd is happening here: count 2:  340 count 1:  344 33.0 0.0
# 3: something odd is happening here: count 3: 347 count 0: 329 75: 30.0 25: 0.0
# 3: something odd is happening here: count 3: 315 count 0: 305 75: 61.0 25: 0.0
# 2: something odd is happening here: count 3:  372 count 2:  371 0.0 5.0
# 3: something odd is happening here: count 3: 323 count 0: 300 75: 54.0 25: 0.0
# 1: something odd is happening here: count 2:  322 count 1:  344 33.0 0.0
# 1: something odd is happening here: count 2:  368 count 1:  371 6.0 0.0
# 3: something odd is happening here: count 3: 331 count 0: 307 75: 46.0 25: 0.0
# 3: something odd is happening here: count 3: 375 count 0: 373 75: 2.0 25: 0.0
# 3: something odd is happening here: count 3: 299 count 0: 294 75: 78.0 25: 0.0
# 0: something odd is happening here: count 1:  338 count 0:  343 33.0 0.0
# 0: something odd is happening here: count 1:  330 count 0:  347 30.0 0.0
# 3: something odd is happening here: count 3: 325 count 0: 301 75: 52.0 25: 0.0
# 3: something odd is happening here: count 3: 321 count 0: 289 75: 56.0 25: 0.0
# 0: something odd is happening here: count 1:  372 count 0:  375 2.0 0.0
# 0: something odd is happening here: count 1:  360 count 0:  361 15.0 0.0
# 3: something odd is happening here: count 3: 291 count 0: 258 75: 86.0 25: 0.0
# 2: something odd is happening here: count 3:  341 count 2:  351 26.0 0.0
# 2: something odd is happening here: count 3:  341 count 2:  354 22.0 0.0
# 1: something odd is happening here: count 2:  333 count 1:  344 33.0 0.0
# 2: something odd is happening here: count 3:  333 count 2:  346 31.0 0.0
# 1: something odd is happening here: count 2:  359 count 1:  361 0.0 15.0
# 2: something odd is happening here: count 3:  297 count 2:  319 58.0 0.0
# 1: something odd is happening here: count 2:  296 count 1:  308 68.0 0.0
# 0: something odd is happening here: count 1:  337 count 0:  341 36.0 0.0
# 3: something odd is happening here: count 3: 290 count 0: 261 75: 87.0 25: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-c7a3a4963e8a> in <cell line: 187>()
#     185 sequence_length = 1500
#     186
# --> 187 result_sequence = generate_sequence_from_matrix(condition = "ordered",stimuli = tones, len_sequence = 1504)
#     188 # --> with 1500 stimuli and 4 stimuli, you will never have non-float numbers for the absolute numbers of transitions, so
#     189 # by definition, the transition probabilities CAN'T match the 25% and 75% if we don't use
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     159                   print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
#     160                   # couldn't find solution - recursion!
# --> 161                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     162             # update counter:
#     163             if next_stimulus_index == 0:
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#      80                   print("0: something odd is happening here:", "count 1: ", count_1, "count 0: ", count_0, count75_0, count25_0)
#      81                   # couldn't find solution - recursion!
# ---> 82                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#      83             # STIMULUS 1:
#      84             # If the current stimulus is 1 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#      80                   print("0: something odd is happening here:", "count 1: ", count_1, "count 0: ", count_0, count75_0, count25_0)
#      81                   # couldn't find solution - recursion!
# ---> 82                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#      83             # STIMULUS 1:
#      84             # If the current stimulus is 1 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     159                   print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
#     160                   # couldn't find solution - recursion!
# --> 161                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     162             # update counter:
#     163             if next_stimulus_index == 0:
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     133                   print("2: something odd is happening here:", "count 3: ", count_3, "count 2: ", count_2, count75_2, count25_2)
#     134                   # couldn't find solution - recursion!
# --> 135                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     136             # STIMULUS 3:
#     137             # If the current stimulus is 3 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#      80                   print("0: something odd is happening here:", "count 1: ", count_1, "count 0: ", count_0, count75_0, count25_0)
#      81                   # couldn't find solution - recursion!
# ---> 82                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#      83             # STIMULUS 1:
#      84             # If the current stimulus is 1 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
# ...
#     107                   # couldn't find solution - recursion!
# --> 108                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     109             # STIMULUS 2:
#     110             # If the current stimulus is 2 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     133                   print("2: something odd is happening here:", "count 3: ", count_3, "count 2: ", count_2, count75_2, count25_2)
#     134                   # couldn't find solution - recursion!
# --> 135                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     136             # STIMULUS 3:
#     137             # If the current stimulus is 3 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     106                   print("1: something odd is happening here:", "count 2: ", count_2, "count 1: ", count_1, count75_1, count25_1)
#     107                   # couldn't find solution - recursion!
# --> 108                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     109             # STIMULUS 2:
#     110             # If the current stimulus is 2 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     159                   print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
#     160                   # couldn't find solution - recursion!
# --> 161                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     162             # update counter:
#     163             if next_stimulus_index == 0:
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     159                   print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
#     160                   # couldn't find solution - recursion!
# --> 161                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     162             # update counter:
#     163             if next_stimulus_index == 0:
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     133                   print("2: something odd is happening here:", "count 3: ", count_3, "count 2: ", count_2, count75_2, count25_2)
#     134                   # couldn't find solution - recursion!
# --> 135                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     136             # STIMULUS 3:
#     137             # If the current stimulus is 3 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     159                   print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
#     160                   # couldn't find solution - recursion!
# --> 161                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     162             # update counter:
#     163             if next_stimulus_index == 0:
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     106                   print("1: something odd is happening here:", "count 2: ", count_2, "count 1: ", count_1, count75_1, count25_1)
#     107                   # couldn't find solution - recursion!
# --> 108                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     109             # STIMULUS 2:
#     110             # If the current stimulus is 2 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     106                   print("1: something odd is happening here:", "count 2: ", count_2, "count 1: ", count_1, count75_1, count25_1)
#     107                   # couldn't find solution - recursion!
# --> 108                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     109             # STIMULUS 2:
#     110             # If the current stimulus is 2 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     159                   print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
#     160                   # couldn't find solution - recursion!
# --> 161                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     162             # update counter:
#     163             if next_stimulus_index == 0:
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     159                   print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
#     160                   # couldn't find solution - recursion!
# --> 161                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     162             # update counter:
#     163             if next_stimulus_index == 0:
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     159                   print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
#     160                   # couldn't find solution - recursion!
# --> 161                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     162             # update counter:
#     163             if next_stimulus_index == 0:
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#      80                   print("0: something odd is happening here:", "count 1: ", count_1, "count 0: ", count_0, count75_0, count25_0)
#      81                   # couldn't find solution - recursion!
# ---> 82                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#      83             # STIMULUS 1:
#      84             # If the current stimulus is 1 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#      80                   print("0: something odd is happening here:", "count 1: ", count_1, "count 0: ", count_0, count75_0, count25_0)
#      81                   # couldn't find solution - recursion!
# ---> 82                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#      83             # STIMULUS 1:
#      84             # If the current stimulus is 1 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     159                   print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
#     160                   # couldn't find solution - recursion!
# --> 161                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     162             # update counter:
#     163             if next_stimulus_index == 0:
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     159                   print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
#     160                   # couldn't find solution - recursion!
# --> 161                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     162             # update counter:
#     163             if next_stimulus_index == 0:
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#      80                   print("0: something odd is happening here:", "count 1: ", count_1, "count 0: ", count_0, count75_0, count25_0)
#      81                   # couldn't find solution - recursion!
# ---> 82                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#      83             # STIMULUS 1:
#      84             # If the current stimulus is 1 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#      80                   print("0: something odd is happening here:", "count 1: ", count_1, "count 0: ", count_0, count75_0, count25_0)
#      81                   # couldn't find solution - recursion!
# ---> 82                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#      83             # STIMULUS 1:
#      84             # If the current stimulus is 1 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     159                   print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
#     160                   # couldn't find solution - recursion!
# --> 161                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     162             # update counter:
#     163             if next_stimulus_index == 0:
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     133                   print("2: something odd is happening here:", "count 3: ", count_3, "count 2: ", count_2, count75_2, count25_2)
#     134                   # couldn't find solution - recursion!
# --> 135                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     136             # STIMULUS 3:
#     137             # If the current stimulus is 3 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     133                   print("2: something odd is happening here:", "count 3: ", count_3, "count 2: ", count_2, count75_2, count25_2)
#     134                   # couldn't find solution - recursion!
# --> 135                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     136             # STIMULUS 3:
#     137             # If the current stimulus is 3 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     106                   print("1: something odd is happening here:", "count 2: ", count_2, "count 1: ", count_1, count75_1, count25_1)
#     107                   # couldn't find solution - recursion!
# --> 108                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     109             # STIMULUS 2:
#     110             # If the current stimulus is 2 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     133                   print("2: something odd is happening here:", "count 3: ", count_3, "count 2: ", count_2, count75_2, count25_2)
#     134                   # couldn't find solution - recursion!
# --> 135                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     136             # STIMULUS 3:
#     137             # If the current stimulus is 3 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     106                   print("1: something odd is happening here:", "count 2: ", count_2, "count 1: ", count_1, count75_1, count25_1)
#     107                   # couldn't find solution - recursion!
# --> 108                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     109             # STIMULUS 2:
#     110             # If the current stimulus is 2 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     133                   print("2: something odd is happening here:", "count 3: ", count_3, "count 2: ", count_2, count75_2, count25_2)
#     134                   # couldn't find solution - recursion!
# --> 135                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     136             # STIMULUS 3:
#     137             # If the current stimulus is 3 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     106                   print("1: something odd is happening here:", "count 2: ", count_2, "count 1: ", count_1, count75_1, count25_1)
#     107                   # couldn't find solution - recursion!
# --> 108                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     109             # STIMULUS 2:
#     110             # If the current stimulus is 2 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#      80                   print("0: something odd is happening here:", "count 1: ", count_1, "count 0: ", count_0, count75_0, count25_0)
#      81                   # couldn't find solution - recursion!
# ---> 82                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#      83             # STIMULUS 1:
#      84             # If the current stimulus is 1 and we still have enough stimuli left of
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     159                   print("3: something odd is happening here:", "count 3:", count_3, "count 0:", count_0, "75:", count75_3, "25:", count25_3)
#     160                   # couldn't find solution - recursion!
# --> 161                   generate_sequence_from_matrix(condition = condition, stimuli = stimuli, len_sequence = len_sequence)
#     162             # update counter:
#     163             if next_stimulus_index == 0:
#
# <ipython-input-106-c7a3a4963e8a> in generate_sequence_from_matrix(condition, stimuli, len_sequence)
#     140               if count_3 < (len_sequence / num_stimuli) and count_0 < (len_sequence / num_stimuli) and count75_3 > 0 and count25_3 > 0:
#     141                 # randomly choose next stimulus based on our pre-defined probabilities:
# --> 142                 next_stimulus_index = random.choices([3,0], [.25, .75])[0]
#     143                 if next_stimulus_index == 0:
#     144                   count75_3 = count75_3 - 1 # one less transition from 3 to 0 left - update counter!
#
# /usr/lib/python3.10/random.py in choices(self, population, weights, cum_weights, k)
#     519                 return [population[floor(random() * n)] for i in _repeat(None, k)]
#     520             try:
# --> 521                 cum_weights = list(_accumulate(weights))
#     522             except TypeError:
#     523                 if not isinstance(weights, int):
#
# KeyboardInterrupt:

# %%
# this doesn't work without PsychoPy's sound module

''' PREP SOUNDS FOR RANDOM SEQUENCE: '''

# create an empty dict to store the prepared sounds
tones_random = {}

# loop over list random_sequence with all frequencies
for tone_idx, curr_freq in enumerate(random_sequence):

    print("curent frequency:", curr_freq)

    # build a time array: you need the sound duration and the right sampling frequency for your device
    # 1 divided by the sampling rate = duration of a single sample in sec
    tone_sample_len = 1/audio_sample_freq
    t = np.arange(0, tone_duration, tone_sample_len)

    # generate sine wave:
    sine_wave = np.sin(2*np.pi*curr_freq*t)

    # plot the sine wave
    plt.plot(t, sine_wave)
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.show()

    # Apply cosine ramp to "smoothen" the edges of the sound a bit (I'm not an audio expert as you can tell)
    # We basically gradually turn up the sound, play it for a while,
    # and then decrease the volume again so it doesn't make annoying clicky noises when it's played.

    # apply cosine ramp:
    # check how many samples we have to use for the fade in/out:
    fade_samples = int(tone_fade * audio_sample_freq)

    # if there are enough, but not too many fade samples,
    # apply cosine ramp to signal
    if fade_samples > 0 and fade_samples < len(sine_wave):
      ramp = np.cos(np.linspace(0, np.pi / 2, fade_samples))
      sine_wave[:fade_samples] *= ramp[::-1]
      sine_wave[-fade_samples:] *= ramp

    # plot the modified sine wave again
    plt.plot(t, sine_wave)
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.show()

    print("----------------------")


    # generate sound object for the sound file we built
    sound = Sound(value = sine_wave,
                  secs = tone_duration, # duration of sound in seconds
                  sampleRate = sRate,
                  name = f"tone{tone_idx + 1}", # create a name for the sound for logging
                  hamming = False, # don't apply filter, we did this before
                  volume = tone_volume,
                  loops = 0) # don't repeat sound, play only once

    # add the sound to the dict
    tones_random[f"tone{tone_idx + 1}_random"] = sound





''' PREP SOUNDS FOR ORDERED SEQUENCE: '''

# create an empty dict to store the prepared sounds
tones_ordered = {}

# loop over list ordered_sequence with all frequencies
for tone_idx, curr_freq in enumerate(ordered_sequence):

    print("curent frequency:", curr_freq)

    # build a time array: you need the sound duration and the right sampling frequency for your device
    # 1 divided by the sampling rate = duration of a single sample in sec
    tone_sample_len = 1/audio_sample_freq
    t = np.arange(0, tone_duration, tone_sample_len)

    # generate sine wave:
    sine_wave = np.sin(2*np.pi*curr_freq*t)

    # plot the sine wave
    plt.plot(t, sine_wave)
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.show()

    # Apply cosine ramp to "smoothen" the edges of the sound a bit (I'm not an audio expert as you can tell)
    # We basically gradually turn up the sound, play it for a while,
    # and then decrease the volume again so it doesn't make annoying clicky noises when it's played.

    # apply cosine ramp:
    # check how many samples we have to use for the fade in/out:
    fade_samples = int(tone_fade * audio_sample_freq)

    # if there are enough, but not too many fade samples,
    # apply cosine ramp to signal
    if fade_samples > 0 and fade_samples < len(sine_wave):
      ramp = np.cos(np.linspace(0, np.pi / 2, fade_samples))
      sine_wave[:fade_samples] *= ramp[::-1]
      sine_wave[-fade_samples:] *= ramp

    # plot the modified sine wave again
    plt.plot(t, sine_wave)
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.show()

    print("----------------------")


    # generate sound object for the sound file we built
    sound = Sound(value = sine_wave,
                  secs = tone_duration, # duration of sound in seconds
                  sampleRate = sRate,
                  name = f"tone{tone_idx + 1}", # create a name for the sound for logging
                  hamming = False, # don't apply filter, we did this before
                  volume = tone_volume,
                  loops = 0) # don't repeat sound, play only once

    # add the sound to the dict
    tones_ordered[f"tone{tone_idx + 1}_ordered"] = sound

# now you can access & play each sound by its name, like this:
#now = ptb.GetSecs()
#tones_ordered["tone1_ordered"].play(when = now)  # Play the first sound immediately
#core.wait(1.5) # wait until sound is finished
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-eac3914d335f> in <cell line: 9>()
#       7
#       8 # loop over list random_sequence with all frequencies
# ----> 9 for tone_idx, curr_freq in enumerate(random_sequence):
#      10
#      11     print("curent frequency:", curr_freq)
#
# NameError: name 'random_sequence' is not defined
